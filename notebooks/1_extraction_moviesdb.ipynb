# %% [markdown]
# ### 0. Imports

# %%
# Data transformation
# ---------------------------------------
import pandas as pd
import polars as pl

# API calls
# ---------------------------------------
import requests

# Scraping
# ---------------------------------------
from bs4 import BeautifulSoup


# Aynchronicity
# ---------------------------------------
import asyncio
import aiohttp


import json


import time

# %% [markdown]
# # 1. Introducción - Extracción datos Movies Database

# %% [markdown]
# Este notebook detalla la exploración acarreada para la extracción de datos a través de la API Movies Database.

# %% [markdown]
# # 2. Extraccion

# %% [markdown]
# - Películas desde 1990 hasta la actualidad.
# - Géneros: Drama, Comedy, Action, Fantasy, Horror, Mystery, Romance, Thriller.
# - Información necesaria:
#   - Tipo (corto o película).
#   - Nombre.
#   - Año y mes de estreno.
#   - ID de la película.

# %% [markdown]
# Request de ejemplo:

# %%
url = "https://moviesdatabase.p.rapidapi.com/titles"

querystring = {"genre":"Drama","startYear":"1990","titleType":"movie","page":"70","limit":"50"}

headers = {
	"x-rapidapi-key": "c09b699b97mshc664835db7a2ca3p1f803fjsn67c91d35ded1",
	"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'page': 1, 'next': '/titles?titleType=movie&genre=Drama&page=2&limit=50&startYear=1990', 'entries': 50, 'results': [{'_id': '662feb6b06e751c276d800b8', 'id': 'tt32230923', 'primaryImage': {'id': 'rm3377102337', 'width': 768, 'height': 1344, 'url': 'https://m.media-amazon.com/images/M/MV5BNzA0Zjc3MzMtZWZkYi00OWI3LWJiOGQtYTQwYjgxZjBiNjg2XkEyXkFqcGdeQXVyMTgwNjM0NzY3._V1_.jpg', 'caption': {'plainText': 'Sardar Soleimani (2027)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Sardar Soleimani', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Sardar Soleimani', '__typename': 'TitleText'}, 'releaseYear': {'year': 2027, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 31, 'month': 12, 'year': 2027, '__typename': 'ReleaseDate'}}, {'_id': '61e5975278c012aa34468cdb', 'id': 'tt12053936', 'primaryImage': {'id': 'rm3428067841', 'width': 1728, 'height': 2304, 'url': 'https://m.media-amazon.com/images/M/MV5BOGEzNWQ4NTMtZmU4Mi00NmJkLWJlYzUtOWFmNGRkYzAyNWM2XkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Mike Breyer and Lynne Newton in Eternal Oath (2026)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Eternal Oath', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Eternal Oath', '__typename': 'TitleText'}, 'releaseYear': {'year': 2026, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 30, 'month': 12, 'year': 2026, '__typename': 'ReleaseDate'}}, {'_id': '61e59b71a66e59642347962d', 'id': 'tt12767592', 'primaryImage': {'id': 'rm1992317697', 'width': 632, 'height': 572, 'url': 'https://m.media-amazon.com/images/M/MV5BZGJmYzA5ZmUtZGU3NS00NGMxLTliYzktYmEwMTE5N2RhYzAzXkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'After dark (2026)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'After dark', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'After dark', '__typename': 'TitleText'}, 'releaseYear': {'year': 2026, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': 1, 'month': 5, 'year': 2026, '__typename': 'ReleaseDate'}}, {'_id': '61e5bf42a66e5964235049d5', 'id': 'tt4707214', 'primaryImage': {'id': 'rm848495360', 'width': 1275, 'height': 1875, 'url': 'https://m.media-amazon.com/images/M/MV5BNGRkYTVjZjktNjJmNi00NDdmLWFkMWMtMzM4MWFlMjAxODZmXkEyXkFqcGc@._V1_.jpg', 'caption': {'plainText': 'Loud (2026)', '__typename': 'Markdown'}, '__typename': 'Image'}, 'titleType': {'displayableProperty': {'value': {'plainText': '', '__typename': 'Markdown'}, '__typename': 'DisplayableTitleTypeProperty'}, 'text': 'Movie', 'id': 'movie', 'isSeries': False, 'isEpisode': False, 'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}], 'canHaveEpisodes': False, '__typename': 'TitleType'}, 'titleText': {'text': 'Loud', '__typename': 'TitleText'}, 'originalTitleText': {'text': 'Loud', '__typename': 'TitleText'}, 'releaseYear': {'year': 2026, 'endYear': None, '__typename': 'YearRange'}, 'releaseDate': {'day': No ...

# %% [markdown]
# Hay paginación. No se conoce el límite de páginas por género y tipo de cinta.
#
# Dado que hay 1000 consultas por hora, que hay que hacer consultas separadas para 'short' y para 'movie', así como para los géneros, se puede tratar de intentar un approach rápido por asincronía de hacer todas las consultas en lugar usar un bucle que trate de encontrar el límite de páginas para cada uno, con el consiguiente tiempo de diseño de la lógica para capturarlo.

# %% [markdown]
# Extraer campos de requeridos de cada pelicula.

# %%
# page
response.json()
# id 
response.json()["results"][0]["id"]
# type
response.json()["results"][0]["titleType"]["id"]

# nombre
response.json()["results"][0]["titleText"]["text"]

# año y mes de estreno
response.json()["results"][0]["releaseDate"]["year"]
response.json()["results"][0]["releaseDate"]["month"]
# Out:
# 12

# %%
# miguellv96@gmail.com
headers = {
    "x-rapidapi-key": "c09b699b97mshc664835db7a2ca3p1f803fjsn67c91d35ded1",
    "x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
}


# miguel.lopezvirues@alum.uca.es
headers = {
    'x-rapidapi-key': "5027380e12msh3259c6d3e08bbe5p1b31bbjsn6f9e42d6d53b",
    'x-rapidapi-host': "moviesdatabase.p.rapidapi.com"
}

# miguel.lopezvirues@gmail.com
headers = {
    'x-rapidapi-key': "98ab80c541msh548e16e3c595c79p101433jsn6131790668a3",
    'x-rapidapi-host': "moviesdatabase.p.rapidapi.com"
}

# hackio projects 1
headers = {
    "x-rapidapi-key": "997763c3bamsheeaaefa4d7efc72p100dcfjsnc6ba0f0812da",
    "x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
}

# hackio projects 2 
headers = {
	"x-rapidapi-key": "d42d6bd155mshfbdc1f0c83f26f5p12fca4jsnf8aa6552f0e5",
	"x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
}

# %%
async def request_movies_async(querystring):
    
    url = "https://moviesdatabase.p.rapidapi.com/titles"

    headers = {
        "x-rapidapi-key": "c09b699b97mshc664835db7a2ca3p1f803fjsn67c91d35ded1",
        "x-rapidapi-host": "moviesdatabase.p.rapidapi.com"
    }

    async with aiohttp.ClientSession() as session:
        async with session.get(url, headers=headers, params=querystring) as response:
            if response.status == 500:
                print(f"Max operation time for querystring {querystring}. Retrying...")
                await asyncio.sleep(3)  # Wait for 3 seconds before retrying
                return await request_movies_async(querystring)  # Retry the same request
            elif response.status == 200:
                try:
                    results = await response.json()
                    pagina = results["page"]
                    results = results["results"]
                    for result in results:
                        result["pagina"] = pagina
                        result["genre"] = querystring["genre"]

                except KeyError as e:
                    print(f"KeyError with querystring {querystring}: {e}")
                    return []  # returning an empty list for consistency
                except TypeError as e:
                    print(f"TypeError with querystring {querystring}: {e}")
                    return []
                except Exception as e:
                    print(f"Unexpected error with querystring {querystring}: {e}")
                    return []
            else:
                print(f"Request failed with status {response.status} for {querystring}")
                return []
                raise ValueError(f"HTTP Error: {response.status}")
            

    return results

async def get_movies_info(querystring_list): 

    tasks = [request_movies_async(querystring) for querystring in querystring_list]
    results = await asyncio.gather(*tasks)

    return results

# %%
def create_querystrings(end_page, title_type_list, genres_list, start_year):
    querystring_list = []

    for page in range(1,end_page+1):
        for title_type in title_type_list:
            for genre in genres_list:
                base_querystring = {"genre":None,"startYear":str(start_year),"titleType":None,"page":None,"limit":"50","sort":"year.incr"}

                base_querystring["genre"] = genre
                base_querystring["titleType"] = title_type
                base_querystring["page"] = page

                querystring_list.append(base_querystring)

    return querystring_list

# %% [markdown]
# Creación de función de extracción de datos:

# %%
def generar_lista_tuplas(lista_jsons):

    lista_tuplas_peliculas = []
    for response in lista_jsons:
        # page
        page = response["pagina"]
        # id 
        id = response["id"]
        # type
        title_type = response["titleType"]["id"]

        # nombre

        title = response["titleText"]["text"]

        # año y mes de estreno

        try:
            
            year = response["releaseDate"]["year"]
            month = response["releaseDate"]["month"]
        except:

            year = response["releaseYear"]["year"]
            month = None

        # genre
        genre = response["genre"]

        pelicula_tupla = (page, id, title_type, title, genre, year, month)

        lista_tuplas_peliculas.append(pelicula_tupla)

    return lista_tuplas_peliculas

# %%
test_querystring_list = create_querystrings(1, ["movie"],["Drama"],1990)

results = await get_movies_info(test_querystring_list)

resultados_flat = [sublista for lista in results for sublista in lista]

generar_lista_tuplas(resultados_flat)
# Out:
# [('1', 'tt0059325', 'movie', 'Jahrgang 45', 'Drama', 1990, 10),
#  ('1',
#   'tt0059900',
#   'movie',
#   'Wenn du groß bist, lieber Adam',
#   'Drama',
#   1990,
#   10),
#  ('1', 'tt0065188', 'movie', 'Vojtech, receny sirotek', 'Drama', 1990, 10),
#  ('1', 'tt0068494', 'movie', 'Domo Arigato', 'Drama', 1990, 8),
#  ('1', 'tt0075259', 'movie', 'Spy Story', 'Drama', 1990, 3),
#  ('1', 'tt0081721', 'movie', 'Vincent et moi', 'Drama', 1990, 12),
#  ('1', 'tt0090665', 'movie', 'Asfour Stah', 'Drama', 1991, 3),
#  ('1', 'tt0093210', 'movie', 'La hora 24', 'Drama', 1990, None),
#  ('1', 'tt0093989', 'movie', 'Xian sha lu', 'Drama', 1990, 11),
#  ('1', 'tt0093662', 'movie', 'Object of Desire', 'Drama', 1990, None),
#  ('1', 'tt0094666', 'movie', "Any Man's Death", 'Drama', 1990, 5),
#  ('1', 'tt0094073', 'movie', 'The Sun and the Moon', 'Drama', 1990, 10),
#  ('1', 'tt0094857', 'movie', 'Chi se da feng bao', 'Drama', 1990, 3),
#  ('1', 'tt0095840', 'movie', 'Payback', 'Drama', 1990, 4),
#  ('1', 'tt0096469', 'movie', 'Wu ye tian shi', 'Drama', 1990, 10),
#  ('1', 'tt0096775', 'movie', 'Agneekaal', 'Drama', 1990, 10),
#  ('1', 'tt0096992', 'movie', 'Bumazhnye glaza Prishvina', 'Drama', 1990, 2),
#  ('1',
#   'tt0096937',
#   'movie',
#   'Blagorodnyy razboynik Vladimir Dubrovskiy',
#   'Drama',
#   1990,
#   1),
#  ('1', 'tt0096025', 'movie', "Sailors Don't Cry", 'Drama', 1990, 6),
#  ('1', 'tt0096174', 'movie', 'Stela', 'Drama', 1990, 5),
#  ('1', 'tt0095902', 'movie', 'Primo Baby', 'Drama', 1990, 8),
#  ('1', 'tt0096500', 'movie', 'Zbabelec', 'Drama', 1990, None),
#  ('1',
#   'tt0096845',
#   'movie',
#   'Atlantic Rhapsody - 52 myndir úr Tórshavn',
#   'Drama',
#   1990,
#   1),
#  ('1', 'tt0097339', 'movie', 'Father', 'Drama', 1990, 8),
#  ('1', 'tt0096817', 'movie', 'Los ángeles', 'Drama', 1991, 11),
#  ('1', 'tt0097129', 'movie', 'Crossing the Line', 'Drama', 1990, 11),
#  ('1', 'tt0097298', 'movie', 'Eternity', 'Drama', 1990, 11),
#  ('1', 'tt0096752', 'movie', 'Abrahams Gold', 'Drama', 1990, 4),
#  ('1', 'tt0097573', 'movie', 'In the Cold of the Night', 'Drama', 1990, 12),
#  ('1', 'tt0096763', 'movie', 'Adultery', 'Drama', 1990, None),
#  ('1', 'tt0097697', 'movie', 'Könnyü vér', 'Drama', 1990, 9),
#  ('1', 'tt0097802', 'movie', 'Mado, poste restante', 'Drama', 1990, 10),
#  ('1', 'tt0098144', 'movie', 'La punyalada', 'Drama', 1990, 1),
#  ('1', 'tt0097968', 'movie', 'Nezný barbar', 'Drama', 1990, 9),
#  ('1', 'tt0098139', 'movie', 'Pont de Varsòvia', 'Drama', 1990, 3),
#  ('1', 'tt0098004', 'movie', 'Nochevala tuchka zolotaya...', 'Drama', 1990, 5),
#  ('1', 'tt0097833', 'movie', 'Marcowe migdaly', 'Drama', 1990, 2),
#  ('1', 'tt0097106', 'movie', 'Conte de printemps', 'Drama', 1991, 2),
#  ('1', 'tt0096875', 'movie', 'Catchfire', 'Drama', 1990, 4),
#  ('1', 'tt0096296', 'movie', 'Tragediya v stile rok', 'Drama', 1990, 2),
#  ('1', 'tt0097115', 'movie', 'Courage Mountain', 'Drama', 1990, 2),
#  ('1', 'tt0096838', 'movie', "L'assassina", 'Drama', 1990, 8),
#  ('1', 'tt0096879', 'movie', 'Bal na dworcu w Koluszkach', 'Drama', 1990, 4),
#  ('1', 'tt0096984', 'movie', 'Brodyachiy avtobus', 'Drama', 1990, 8),
#  ('1', 'tt0097475', 'movie', 'A halálraítélt', 'Drama', 1990, 5),
#  ('1', 'tt0096883', 'movie', 'Ballbuster', 'Drama', 1990, None),
#  ('1', 'tt0098657', 'movie', 'Winckelmanns Reisen', 'Drama', 1991, 11),
#  ('1', 'tt0097348', 'movie', 'Fung yue tung lo', 'Drama', 1990, 5),
#  ('1', 'tt0096825', 'movie', 'Any Time, Any Play', 'Drama', 1990, 11),
#  ('1', 'tt0097738', 'movie', 'La leyenda de una máscara', 'Drama', 1991, 2)]

# %% [markdown]
# Realizar la llamada global:

# %%
genre_list = ["Drama", "Comedy", "Action", "Fantasy", "Horror", "Mystery", "Romance", "Thriller"]
title_type_list =  ["movie","short"]
end_page = 55
end_year = 1990

querystring_list = create_querystrings(end_page, title_type_list,genre_list,end_year)
print("Len of querystring list" ,len(querystring_list))
querystring_list[:10]
# Out:
# Len of querystring list 880
# [{'genre': 'Drama',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Comedy',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Action',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Fantasy',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Horror',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Mystery',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Romance',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Thriller',
#   'startYear': '1990',
#   'titleType': 'movie',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Drama',
#   'startYear': '1990',
#   'titleType': 'short',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'},
#  {'genre': 'Comedy',
#   'startYear': '1990',
#   'titleType': 'short',
#   'page': 1,
#   'limit': '50',
#   'sort': 'year.incr'}]

# %%
results_400 = await get_movies_info(querystring_list[:400])

# %%
results_480 = await get_movies_info(querystring_list[400:])
# Out:
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 33, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 33, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'movie', 'page': 34, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 53, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 48, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'short', 'page': 36, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 47, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 55, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'movie', 'page': 51, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'movie', 'page': 46, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 48, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 44, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 42, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 39, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 39, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'movie', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 42, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 55, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 48, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'movie', 'page': 44, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 41, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'movie', 'page': 43, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 42, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 40, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'short', 'page': 45, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 53, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 47, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 51, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'short', 'page': 40, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 50, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 50, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 44, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 54, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 52, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 45, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 43, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'movie', 'page': 47, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 45, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 42, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 52, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 46, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 54, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'short', 'page': 39, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 51, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 39, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'movie', 'page': 42, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'movie', 'page': 44, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 52, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 40, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 44, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 37, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 45, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'movie', 'page': 40, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 46, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 46, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 37, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 37, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'movie', 'page': 54, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 41, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'short', 'page': 48, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 39, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 41, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Drama', 'startYear': '1990', 'titleType': 'short', 'page': 37, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 50, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 41, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'movie', 'page': 45, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 55, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 52, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'movie', 'page': 47, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 48, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 41, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'movie', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'movie', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'short', 'page': 46, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 53, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'short', 'page': 39, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'movie', 'page': 48, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'movie', 'page': 53, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 55, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 55, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 51, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'movie', 'page': 47, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 38, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 54, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'movie', 'page': 43, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 54, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 53, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 52, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 40, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'short', 'page': 54, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Fantasy', 'startYear': '1990', 'titleType': 'movie', 'page': 55, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'short', 'page': 53, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Comedy', 'startYear': '1990', 'titleType': 'movie', 'page': 37, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Horror', 'startYear': '1990', 'titleType': 'movie', 'page': 51, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Romance', 'startYear': '1990', 'titleType': 'movie', 'page': 43, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Thriller', 'startYear': '1990', 'titleType': 'short', 'page': 42, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Action', 'startYear': '1990', 'titleType': 'short', 'page': 49, 'limit': '50', 'sort': 'year.incr'}
# Request failed with status 429 for {'genre': 'Mystery', 'startYear': '1990', 'titleType': 'short', 'page': 46, 'limit': '50', 'sort': 'year.incr'}

# %%
resultados_400_flat = [sublista for lista in results_400 for sublista in lista]

lista_tuplas_400 = generar_lista_tuplas(resultados_400_flat)
df_400 = pd.DataFrame(lista_tuplas_400)
df_400.to_csv("../data/movies_400.csv")
df_400
# Out:
#         0          1      2                               3         4     5  \
# 0       1  tt0059325  movie                     Jahrgang 45     Drama  1990
# 1       1  tt0059900  movie  Wenn du groß bist, lieber Adam     Drama  1990
# 2       1  tt0065188  movie         Vojtech, receny sirotek     Drama  1990
# 3       1  tt0068494  movie                    Domo Arigato     Drama  1990
# 4       1  tt0075259  movie                       Spy Story     Drama  1990
# ...    ..        ...    ...                             ...       ...   ...
# 19995  25  tt0446926  short               Be Still My Heart  Thriller  2004
# 19996  25  tt0444735  short                            Will  Thriller  2004
# 19997  25  tt0445019  short                            Jill  Thriller  2004
# 19998  25  tt0446543  short                      Black Jack  Thriller  2004
# 19999  25  tt0445721  short                          Skvira  Thriller  2004
#
#           6
# 0      10.0
# 1      10.0
# 2      10.0
# 3       8.0
# 4       3.0
# ...     ...
# 19995   NaN
# 19996  12.0
# 19997   4.0
# 19998   NaN
# 19999  11.0
#
# [20000 rows x 7 columns]

# %%
resultados_480_flat = [sublista for lista in results_480 for sublista in lista]

lista_tuplas_480 = generar_lista_tuplas(resultados_480_flat)
df_480 = pd.DataFrame(lista_tuplas_480)
df_480.to_csv("../data/movies_480.csv")

df_480
# Out:
#         0           1      2                                         3  \
# 0      26  tt10883110  movie                             Aji Pamungkas
# 1      26   tt1090298  movie                     Ali va ghool-e jangal
# 2      26  tt11016436  movie                     Bing leng de tai yang
# 3      26   tt1102282  movie                            Naghsh-e eshgh
# 4      26  tt11162952  movie                Ricky (Nakalnya Anak Muda)
# ...    ..         ...    ...                                       ...
# 18595   1  tt30185433  short  Hello Kitty no Mahô no Mori no Ohimesama
# 18596   1  tt32513765  short                                 1991=HERE
# 18597   1   tt0101777  short                               Drum Struck
# 18598   1   tt0101292  short                                Alcibíades
# 18599   1   tt0104285  short                                     Jídlo
#
#              4     5    6
# 0        Drama  1990  NaN
# 1        Drama  1990  NaN
# 2        Drama  1990  NaN
# 3        Drama  1990  NaN
# 4        Drama  1990  NaN
# ...        ...   ...  ...
# 18595  Fantasy  1991  7.0
# 18596  Fantasy  1991  1.0
# 18597  Fantasy  1992  4.0
# 18598  Fantasy  1992  NaN
# 18599  Fantasy  1992  6.0
#
# [18600 rows x 7 columns]

# %%
df_total = pd.concat([df_400, df_480],axis=0)
df_total.columns = ["pagina","id","tipo_titulo","titulo","genero","año","mes"]
df_total
# Out:
#       pagina          id tipo_titulo  \
# 0          1   tt0059325       movie
# 1          1   tt0059900       movie
# 2          1   tt0065188       movie
# 3          1   tt0068494       movie
# 4          1   tt0075259       movie
# ...      ...         ...         ...
# 18595      1  tt30185433       short
# 18596      1  tt32513765       short
# 18597      1   tt0101777       short
# 18598      1   tt0101292       short
# 18599      1   tt0104285       short
#
#                                          titulo   genero   año   mes
# 0                                   Jahrgang 45    Drama  1990  10.0
# 1                Wenn du groß bist, lieber Adam    Drama  1990  10.0
# 2                       Vojtech, receny sirotek    Drama  1990  10.0
# 3                                  Domo Arigato    Drama  1990   8.0
# 4                                     Spy Story    Drama  1990   3.0
# ...                                         ...      ...   ...   ...
# 18595  Hello Kitty no Mahô no Mori no Ohimesama  Fantasy  1991   7.0
# 18596                                 1991=HERE  Fantasy  1991   1.0
# 18597                               Drum Struck  Fantasy  1992   4.0
# 18598                                Alcibíades  Fantasy  1992   NaN
# 18599                                     Jídlo  Fantasy  1992   6.0
#
# [38600 rows x 7 columns]

# %%
df_total = df_total.drop_duplicates(subset="id")
df_total.to_csv("../data/movies_total.csv")
