# %% [markdown]
# ### 0. Imports

# %%
# Data transformation
# ---------------------------------------
import pandas as pd
import polars as pl

# API calls
# ---------------------------------------
import requests

# Scraping
# ---------------------------------------
from bs4 import BeautifulSoup


# Aynchronicity
# ---------------------------------------
import asyncio
import aiohttp


import json


import time


import re

from tqdm import tqdm

from joblib import Parallel, delayed

import sys

if sys.platform == 'win32':
    loop = asyncio.ProactorEventLoop()
    asyncio.set_event_loop(loop)

# %% [markdown]
# # 1. Introducción - Extracción datos Movies Database

# %% [markdown]
# Este notebook detalla la exploración acarreada para la extracción de datos a través de la API Movies Database.

# %% [markdown]
# # 2. Extraccion

# %% [markdown]
# - Calificación de IMDB.
# - Dirección (director o directores).
# - Guionistas.
# - Argumento.
# - Duración (en minutos).

# %% [markdown]
# Ejemplo para una sola pelicula: 'tt4495760'

# %%
url = "https://www.imdb.com/es-es/title/tt4495760/?ref_=fn_all_ttl_1"

headers={"User-Agent": "Chrome"}

response = requests.get(url,headers=headers)

sopa = BeautifulSoup(response.content, "html.parser")

sopa
# Out:
# <!DOCTYPE html>
# <html lang="es-ES" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/"><head><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><script>if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1734359006562);
#         }
#     })</script><title>Shtemp (1991) - IMDb</title><meta content="Shtemp: Dirigido por Gennadiy Ivanov. Con Anatoliy Khostikoev, Yelena Kolchugina, Guram Pirtskhalava, Igor Shapovalov. Criminal Investigation Inspector Arkady Ershov is investigating a case related to the Moscow mafia." data-id="main" name="description"/><meta content="Reseñas, Horarios, DVD, Fotos, Calificaciones de los Usuarios, Sinopsis, Tráileres, Créditos" name="keywords"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"Movie","url":"https://www.imdb.com/title/tt4495760/","name":"Shtemp","image":"https://m.media-amazon.com/images/M/MV5BZTkzMTFmNGItZjRlNS00NDQ1LWIwNzEtODNhYmRhYWRjZWU4XkEyXkFqcGc@._V1_.jpg","description":"Criminal Investigation Inspector Arkady Ershov is investigating a case related to the Moscow mafia.","aggregateRating":{"@type":"AggregateRating","ratingCount":29,"bestRating":10,"worstRating":1,"ratingValue":5.6},"genre":["Acción"],"keywords":"escape from jail,karate,corrupción,milicia,inspector","actor":[{"@type":"Person","url":"https://www.imdb.com/name/nm0451857/","name":"Anatoliy Khostikoev"},{"@type":"Person","url":"https://www.imdb.com/name/nm0463967/","name":"Yelena Kolchugina"},{"@type":"Person","url":"https://www.imdb.com/name/nm0685345/","name":"Guram Pirtskhalava"}],"director":[{"@type":"Person","url":"https://www.imdb.com/name/nm0412042/","name":"Gennadiy Ivanov"}],"creator":[{"@type":"Organization","url":"https://www.imdb.com/company/co0114226/"},{"@type":"Person","url":"https://www.imdb.com/name/nm0412042/","name":"Gennadiy Ivanov"},{"@type":"Person","url":"https://www.imdb.com/name/nm7164976/","name":"Aleksandr Stashkov"}],"duration":"PT1H32M"}</script><meta content="https://www.imdb.com/es-es/title/tt4495760/" property="og:url"/><meta content="IMDb" property="og:site_name"/><meta content="Shtemp (1991) ⭐ 5.6 | Acción" property="og:title"/><meta content="1h 32m" property="og:description"/><meta content="video.movie" property="og:type"/><meta content="https://m.media-amazon.com/images/M/MV5BZTkzMTFmNGItZjRlNS00NDQ1LWIwNzEtODNhYmRhYWRjZWU4XkEyXkFqcGc@._V1_FMjpg_UX1000_.jpg" property="og:image"/><meta content="1408.0459770114942" property="og:image:height"/><meta content="1000" property="og:image:width"/><meta content="es_ES" property="og:locale"/><meta content="en_US" property="og:locale:alternate"/><meta content="es_MX" property="og:locale:alternate"/><meta content="fr_FR" property="og:locale:alternate"/><meta content="fr_CA" property="og:locale:alternate"/><meta content="it_IT" property="og:locale:alternate"/><meta content="pt_BR" property="og:locale:alternate"/><meta content="hi_IN" property="og:locale:alternate"/><meta content="de_DE" property="og:locale:alternate"/><meta content="@IMDb" property="twitter:site"/><meta content="Shtemp (1991) ⭐ 5.6 | Acción" property="twitter:title"/><meta content="1h 32m" property="twitter:description"/><meta content="summary_large_image" property="twitter:card"/><meta content="https://m.media-amazon.com/images/M/MV5BZTkzMTFmNGItZjRlNS00NDQ1LWIwNzEtODNhYmRhYWRjZWU4XkEyXkFqcGc@._V1_FMjpg_UX1000_.jpg" property="twitter:image"/><meta content="Shtemp: Dirigido por Gennadiy Ivanov. Con Anatoliy Khostikoev, Yelena Kolchugina, Guram Pirtskhalava, Igor Shapovalov. Criminal Investigation Inspector Arkady Ershov is investigating a case related to the Moscow mafia." property="twitter:image:alt"/><link href="https://www.imdb.com/es-es/title/tt4495760/" rel="canonical"/><link href="https://www.imdb.com/title/tt4495760/" hreflang="x-default" rel="alternate"/><link href="https://www.imdb.com/title/tt4495760/" hreflang="en" rel="alternate"/><link href="https://www.imdb.com/de/title/tt4495760/" hreflang="de" rel="alternate"/><link href="https://www.imdb.com/es/title/tt4495760/" hreflang="es" rel="alternate"/><link href="https://www.imdb.com/es-es/title/tt4495760/" hreflang="es-es" rel="alternate"/><link href="https://www.imdb.com/fr/title/tt4495760/" hreflang="fr" rel="alternate"/ ...
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1734359006562);
#         }
#     })</script><script>if(typeof uex === 'function'){ uex('ld', 'LoadTitle', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1734359006562);
#         }
#     })</script><meta content="49" name="next-head-count"/><script>
# var ue_t0=ue_t0||+new Date();
#
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# (function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.shift();)b(a[0],a[1],a[2])};b[a].isStub=1}};e.exec=function(b,a){return function(){try{return b.apply(this,arguments)}catch(c){ueLogError(c,{attribution:a||"undefined",logLevel:"WARN"})}}}})(ue_csm);
#
#
#     var ue_err_chan = 'jserr';
# (function(d,e){function h(f,b){if(!(a.ec>a.mxe)&&f){a.ter.push(f);b=b||{};var c=f.logLevel||b.logLevel;c&&c!==k&&c!==m&&c!==n&&c!==p||a.ec++;c&&c!=k||a.ecf++;b.pageURL=""+(e.location?e.location.href:"");b.logLevel=c;b.attribution=f.attribution||b.attribution;a.erl.push({ex:f,info:b})}}function l(a,b,c,e,g){d.ueLogError({m:a,f:b,l:c,c:""+e,err:g,fromOnError:1,args:arguments},g?{attribution:g.attribution,logLevel:g.logLevel}:void 0);return!1}var k="FATAL",m="ERROR",n="WARN",p="DOWNGRADED",a={ec:0,ecf:0,
# pec:0,ts:0,erl:[],ter:[],buffer:[],mxe:50,startTimer:function(){a.ts++;setInterval(function(){d.ue&&a.pec<a.ec&&d.uex("at");a.pec=a.ec},1E4)}};l.skipTrace=1;h.skipTrace=1;h.isStub=1;d.ueLogError=h;d.ue_err=a;e.onerror=l})(ue_csm,window);
#
#
# var ue_id = '8YE9G7WMYR0TFHZBMGDB',
#     ue_url,
#     ue_navtiming = 1,
#     ue_mid = 'A1EVAM02EL8SFB',
#     ue_sid = '136-2930362-6872714',
#     ue_sn = 'www.imdb.com',
#     ue_furl = 'fls-na.amazon.com',
#     ue_surl = 'https://unagi-na.amazon.com/1/events/com.amazon.csm.nexusclient.prod',
#     ue_int = 0,
#     ue_fcsn = 1,
#     ue_urt = 3,
#     ue_rpl_ns = 'cel-rpl',
#     ue_ddq = 1,
#     ue_fpf = '//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:136-2930362-6872714:8YE9G7WMYR0TFHZBMGDB$uedata=s:',
#     ue_sbuimp = 1,
#     ue_ibft = 0,
#     ue_sswmts = 0,
#     ue_jsmtf = 0,
#     ue_fnt = 0,
#     ue_lpsi = 6000,
#     ue_no_counters = 0,
#     ue_lob = '6',
#     ue_sjslob = 0,
#     ue_dsbl_cel = 1,
#
#     ue_swi = 1;
# var ue_viz=function(){(function(b,f,d){function g(){return(!(p in d)||0<d[p])&&(!(q in d)||0<d[q])}function h(c){if(b.ue.viz.length<w&&!r){var a=c.type;c=c.originalEvent;/^focus./.test(a)&&c&&(c.toElement||c.fromElement||c.relatedTarget)||(a=g()?f[s]||("blur"==a||"focusout"==a?t:u):t,b.ue.viz.push(a+":"+(+new Date-b.ue.t0)),a==u&&(b.ue.isl&&x("at"),r=1))}}for(var r=0,x=b.uex,a,k,l,s,v=["","webkit","o","ms","moz"],e=0,m=1,u="visible",t="hidden",p="innerWidth",q="innerHeight",w=20,n=0;n<v.length&&!e;n++)if(a=
# v[n],k=(a?a+"H":"h")+"idden",e="boolean"==typeof f[k])l=a+"visibilitychange",s=(a?a+"V":"v")+"isibilityState";h({});e&&f.addEventListener(l,h,0);m=g()?1:0;d.addEventListener("resize",function(){var a=g()?1:0;m!==a&&(m=a,h({}))},{passive:!0});b.ue&&e&&(b.ue.pageViz={event:l,propHid:k})})(ue_csm,ue_csm.document,ue_csm.window)};
#
# (function(d,h,N){function H(a){return a&&a.replace&&a.replace(/^\s+|\s+$/g,"")}function u(a){return"undefined"===typeof a}function B(a,b){for(var c in b)b[v](c)&&(a[c]=b[c])}function I(a){try{var b=N.cookie.match(RegExp("(^| )"+a+"=([^;]+)"));if(b)return b[2].trim()}catch(c){}}function O(k,b,c){var q=(x||{}).type;if("device"!==c||2!==q&&1!==q)k&&(d.ue_id=a.id=a.rid=k,w&&(w=w.replace(/((.*?:){2})(\w+)/,function(a,b){return b+k})),D&&(e("id",D,k),D=0)),b&&(w&&(w=w.replace(/(.*?:)(\w|-)+/,function(a,
# c){return c+b})),d.ue_sid=b),c&&a.tag("page-source:"+c),d.ue_fpf=w}function P(){var a={};return function(b){b&&(a[b]=1);b=[];for(var c in a)a[v](c)&&b.push(c);return b}}function y(d,b,c,q){q=q||+new E;var g,m;if(b||u(c)){if(d)for(m in g=b?e("t",b)||e("t",b,{}):a.t,g[d]=q,c)c[v](m)&&e(m,b,c[m]);return q}}function e(d,b,c){var e=b&&b!=a.id?a.sc[b]:a;e||(e=a.sc[b]={});"id"===d&&c&&(Q=1);return e[d]=c||e[d]}function R(d,b,c,e,g){c="on"+c;var m=b[c];"function"===typeof m?d&&(a.h[d]=m):m=function(){};b[c]=
# function(a){g?(e(a),m(a)):(m(a),e(a))};b[c]&&(b[c].isUeh=1)}function S(k,b,c,q){function p(b,c){var d=[b],f=0,g={},m,h;c?(d.push("m=1"),g[c]=1):g=a.sc;for(h in g)if(g[v](h)){var q=e("wb",h),p=e("t",h)||{},n=e("t0",h)||a.t0,l;if(c||2==q){q=q?f++:"";d.push("sc"+q+"="+h);for(l in p)u(p[l])||null===p[l]||d.push(l+q+"="+(p[l]-n));d.push("t"+q+"="+p[k]);if(e("ctb",h)||e("wb",h))m=1}}!J&&m&&d.push("ctb=1");return d.join("&")}function m(b,c,f,e,g){if(b){var k=d.ue_err;d.ue_url&&!e&&!g&&b&&0<b.length&&(e=
# new Image,a.iel.push(e),e.src=b,a.count&&a.count("postbackImageSize",b.length));w?(g=h.encodeURIComponent)&&b&&(e=new Image,b=""+d.ue_fpf+g(b)+":"+(+new E-d.ue_t0),a.iel.push(e),e.src=b):a.log&&(a.log(b,"uedata",{n:1}),a.ielf.push(b));k&&!k.ts&&k.startTimer();a.b&&(k=a.b,a.b="",m(k,c,f,1))}}function A(b){var c=x?x.type:F,d=2==c||a.isBFonMshop,c=c&&!d,f=a.bfini;if(!Q||a.isBFCache)f&&1<f&&(b+="&bfform=1",c||(a.isBFT=f-1)),d&&(b+="&bfnt=1",a.isBFT=a.isBFT||1),a.ssw&&a.isBFT&&(a.isBFonMshop&&(a.isNRBF=
# 0),u(a.isNRBF)&&(d=a.ssw(a.oid),d.e||u(d.val)||(a.isNRBF=1<d.val?0:1)),u(a.isNRBF)||(b+="&nrbf="+a.isNRBF)),a.isBFT&&!a.isNRBF&&(b+="&bft="+a.isBFT);return b}if(!a.paused&&(b||u(c))){for(var l in c)c[v](l)&&e(l,b,c[l]);a.isBFonMshop||y("pc",b,c);l="ld"===k&&b&&e("wb",b);var s=e("id",b)||a.id;l||s===a.oid||(D=b,ba(s,(e("t",b)||{}).tc||+e("t0",b),+e("t0",b)));var s=e("id",b)||a.id,t=e("id2",b),f=a.url+"?"+k+"&v="+a.v+"&id="+s,J=e("ctb",b)||e("wb",b),z;J&&(f+="&ctb="+J);t&&(f+="&id2="+t);1<d.ueinit&&
# (f+="&ic="+d.ueinit);if(!("ld"!=k&&"ul"!=k||b&&b!=s)){if("ld"==k){try{h[K]&&h[K].isUeh&&(h[K]=null)}catch(I){}if(h.chrome)for(t=0;t<L.length;t++)T(G,L[t]);(t=N.ue_backdetect)&&t.ue_back&&t.ue_back.value++;d._uess&&(z=d._uess());a.isl=1}a._bf&&(f+="&bf="+a._bf());d.ue_navtiming&&g&&(e("ctb",s,"1"),a.isBFonMshop||y("tc",F,F,M));!C||a.isBFonMshop||U||(g&&B(a.t,{na_:g.navigationStart,ul_:g.unloadEventStart,_ul:g.unloadEventEnd,rd_:g.redirectStart,_rd:g.redirectEnd,fe_:g.fetchStart,lk_:g.domainLookupStart,
# _lk:g.domainLookupEnd,co_:g.connectStart,_co:g.connectEnd,sc_:g.secureConnectionStart,rq_:g.requestStart,rs_:g.responseStart,_rs:g.responseEnd,dl_:g.domLoading,di_:g.domInteractive,de_:g.domContentLoadedEventStart,_de:g.domContentLoadedEventEnd,_dc:g.domComplete,ld_:g.loadEventStart,_ld:g.loadEventEnd,ntd:("function"!==typeof C.now||u(M)?0:new E(M+C.now())-new E)+a.t0}),x&&B(a.t,{ty:x.type+a.t0,rc:x.redirectCount+a.t0}),U=1);a.isBFonMshop||B(a.t,{hob:d.ue_hob,hoe:d.ue_hoe});a.ifr&&(f+="&ifr=1")}y(k,
# b,c,q);var r,n;l||b&&b!==s||ca(b);(c=d.ue_mbl)&&c.cnt&&!l&&(f+=c.cnt());l?e("wb",b,2):"ld"==k&&(a.lid=H(s));for(r in a.sc)if(1==e("wb",r))break;if(l){if(a.s)return;f=p(f,null)}else c=p(f,null),c!=f&&(c=A(c),a.b=c),z&&(f+=z),f=p(f,b||a.id);f=A(f);if(a.b||l)for(r in a.sc)2==e("wb",r)&&delete a.sc[r];z=0;a._rt&&(f+="&rt="+a._rt());c=h.csa;if(!l&&c)for(n in r=e("t",b)||{},c=c("PageTiming"),r)r[v](n)&&c("mark",da[n]||n,r[n]);l||(a.s=0,(n=d.ue_err)&&0<n.ec&&n.pec<n.ec&&(n.pec=n.ec,f+="&ec="+n.ec+"&ecf="+
# n.ecf),z=e("ctb",b),"ld"!==k||b||a.markers?a.markers&&a.isl&&!l&&b&&B(a.markers,e("t",b)):(a.markers={},B(a.markers,e("t",b))),e("t",b,{}));a.tag&&a.tag().length&&(f+="&csmtags="+a.tag().join("|"),a.tag=P());n=a.viz||[];(r=n.length)&&(f+="&viz="+n.splice(0,r).join("|"));u(d.ue_pty)||(f+="&pty="+d.ue_pty+"&spty="+d.ue_spty+"&pti="+d.ue_pti);a.tabid&&(f+="&tid="+a.tabid);a.aftb&&(f+="&aftb=1");!a._ui||b&&b!=s||(f+=a._ui());f+="&lob="+(d.ue_lob||"0");a.a=f;m(f,k,z,l,b&&"string"===typeof b&&-1!==b.indexOf("csa:"))}}
# function ca(a){var b=h.ue_csm_markers||{},c;for(c in b)b[v](c)&&y(c,a,F,b[c])}function A(a,b,c){c=c||h;if(c[V])c[V](a,b,!1);else if(c[W])c[W]("on"+a,b)}function T(a,b,c){c=c||h;if(c[X])c[X](a,b,!1);else if(c[Y])c[Y]("on"+a,b)}function Z(){function a(){d.onUl()}function b(a){return function(){c[a]||(c[a]=1,S(a))}}var c={},e,g;d.onLd=b("ld");d.onLdEnd=b("ld");d.onUl=b("ul");e={stop:b("os")};h.chrome?(A(G,a),L.push(a)):e[G]=d.onUl;for(g in e)e[v](g)&&R(0,h,g,e[g]);d.ue_viz&&ue_viz();A("load",d.onLd);
# y("ue")}function ba(e,b,c){var g=d.ue_mbl,p=h.csa,m=p&&p("SPA"),p=p&&p("PageTiming");g&&g.ajax&&g.ajax(b,c);m&&p&&(m("newPage",{requestId:e,transitionType:"soft"}),p("mark","transitionStart",b));a.tag("ajax-transition")}d.ueinit=(d.ueinit||0)+1;var a=d.ue=d.ue||{};a.t0=h.aPageStart||d.ue_t0;a.id=d.ue_id;a.url=d.ue_url;a.rid=d.ue_id;a.a="";a.b="";a.h={};a.s=1;a.t={};a.sc={};a.iel=[];a.ielf=[];a.viz=[];a.v="0.302828.0";a.paused=!1;var v="hasOwnProperty",G="beforeunload",K="on"+G,V="addEventListener",
# X="removeEventListener",W="attachEvent",Y="detachEvent",da={cf:"criticalFeature",af:"aboveTheFold",fn:"functional",fp:"firstPaint",fcp:"firstContentfulPaint",bb:"bodyBegin",be:"bodyEnd",ld:"loaded"},E=h.Date,C=h.performance||h.webkitPerformance,g=(C||{}).timing,x=(C||{}).navigation,M=(g||{}).navigationStart,w=d.ue_fpf,Q=0,U=0,L=[],D=0,F;a.oid=H(a.id);a.lid=H(a.id);a._t0=a.t0;a.tag=P();a.ifr=h.top!==h.self||h.frameElement?1:0;a.markers=null;a.attach=A;a.detach=T;if("000-0000000-8675309"===d.ue_sid){var $=
# I("cdn-rid"),aa=I("session-id");$&&aa&&O($,aa,"cdn")}d.uei=Z;d.ueh=R;d.ues=e;d.uet=y;d.uex=S;a.reset=O;a.pause=function(d){a.paused=d};Z()})(ue_csm,ue_csm.window,ue_csm.document);
#
#
# ue.stub(ue,"log");ue.stub(ue,"onunload");ue.stub(ue,"onflush");
# (function(b){function g(){var a={requestId:b.ue_id||"rid",server:b.ue_sn||"sn",obfuscatedMarketplaceId:b.ue_mid||"mid"};b.ue_sjslob&&(a.lob=b.ue_lob||"0");return a}var a=b.ue,h=1===b.ue_no_counters;a.cv={};a.cv.scopes={};a.cv.buffer=[];a.count=function(b,f,c){var e={},d=a.cv,g=c&&0===c.c;e.counter=b;e.value=f;e.t=a.d();c&&c.scope&&(d=a.cv.scopes[c.scope]=a.cv.scopes[c.scope]||{},e.scope=c.scope);if(void 0===f)return d[b];d[b]=f;d=0;c&&c.bf&&(d=1);h||(ue_csm.ue_sclog||!a.clog||0!==d||g?a.log&&a.log(e,
# "csmcount",{c:1,bf:d}):a.clog(e,"csmcount",{bf:d}));a.cv.buffer.push({c:b,v:f})};a.count("baselineCounter2",1);a&&a.event&&(a.event(g(),"csm","csm.CSMBaselineEvent.4"),a.count("nexusBaselineCounter",1,{bf:1}))})(ue_csm);
#
#
#
# var ue_hoe = +new Date();
# }
# window.ueinit = window.ue_ihb;
#
#
# <!-- pg9h25e -->
# window.ue && ue.count && ue.count('CSMLibrarySize', 10149)</script><script>if(typeof uet === 'function'){ uet('bb', 'LoadAds', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadAds',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1734359006621);
#         }
#     })</script><script>
# window.ads_js_start = new Date().getTime();
# var imdbads = imdbads || {}; imdbads.cmd = imdbads.cmd || [];
# </script><script id="ads_tarnhelm" src="https://m.media-amazon.com/images/S/sash/LDq3HR$47YwxUHD.js"></script><script id="crem_library" src="https://m.media-amazon.com/images/I/11QhRZqmoxL.js"></script><script id="ads_doWithAds">
# doWithAds = function(inside, failureMessage){
# if ('consoleLog' in window &&
# 'generic' in window &&
# 'ad_utils' in window &&
# 'custom' in window &&
# 'monitoring' in generic &&
# 'document_is_ready' in generic) {
# try{
# inside.call(this);
# }catch(e) {
# if ( window.ueLogError ) {
# if(typeof failureMessage !== 'undefined'){
# e.message = failureMessage;
# }
# e.attribution = "Advertising";
# e.logLevel = "ERROR";
# ueLogError(e);
# }
# if( (document.location.hash.match('debug=1')) &&
# (typeof failureMessage !== 'undefined') ){
# console.error(failureMessage);
# }
# }
# } else {
# if( (document.location.hash.match('debug=1')) &&
# (typeof failureMessage !== 'undefined') ){
# console.error(failureMessage);
# }
# }
# };
# </script><script id="ads_monitoring_setup">
# doWithAds(function(){
# generic.monitoring.set_forester_info("title");
# generic.monitoring.start_timing("page_load");
# generic.seconds_to_midnight = 63394;
# generic.days_to_midnight = 0.7337268590927124;
# },"Generic not defined, skipping monitoring setup.");
# </script><script id="safeframe" src="https://m.media-amazon.com/images/S/sash/i$GwBE4XCpFROYA.js"></script><script id="ads_safeframe_setup">
# doWithAds(function(){
# if (typeof DAsf != 'undefined' && typeof DAsf.registerCustomMessageListener === 'function') {
# var ad_utils = window.ad_utils;
# if (ad_utils) {
# if (ad_utils.update_ad_details) {
# DAsf.registerCustomMessageListener('updateAdDetails', window.ad_utils.update_ad_details);
# }
# if (ad_utils.set_partner) {
# DAsf.registerCustomMessageListener('setPartner', window.ad_utils.set_partner);
# }
# DAsf.registerCustomMessageListener('sendMetrics', window.generic.monitoring.update_sf_slot_metrics);
# if (ad_utils.expand_overlay) {
# DAsf.registerCustomMessageListener('expand', window.ad_utils.expand_overlay);
# }
# if (ad_utils.collapse_overlay) {
# DAsf.registerCustomMessageListener('collapse', window.ad_utils.collapse_overlay);
# }
# }
# }
# },"ads js missing, skipping safeframe setup.");
# </script><script id="ads_general_setup">
# doWithAds(function(){
# if (ad_utils && typeof CREM != 'undefined') {
# ad_utils.CREM = CREM;
# }
# generic.monitoring.record_metric("ads_js_request_to_done", (new Date().getTime()) - window.ads_js_start);
# generic.send_csm_head_metrics && generic.send_csm_head_metrics();
# if (ad_utils && ad_utils.set_slots_on_page) {
# ad_utils.set_slots_on_page({ 'inline60_refresh':1, 'inlinebottom_refresh':1, 'inline40_refresh':1, 'inline80_refresh':1, 'promoted_watch_bar':1, 'inline50_refresh':1, 'inlinebottom':1, 'inline20':1, 'provider_promotion':1, 'inline40':1, 'inline20_refresh':1, 'sis_pixel':1, 'inline50':1, 'inline60':1, 'inline80':1 });
# }
# custom.full_page.data_url = "https://m.media-amazon.com/images/S/sash/xToBVcHIRi-lTJp.js";
# consoleLog('advertising initialized','ads');
# },"ads js missing, skipping general setup.");
# </script><script>doWithAds(function() {
# if (ad_utils && ad_utils.ads_header && ad_utils.ads_header.done) {
# ad_utils.ads_header.done();
# }
# });</script><link href="https://m.media-amazon.com/images/S/sash/5efN6gIxDKGfWlp.css" rel="stylesheet"/><script>if(typeof uet === 'function'){ uet('be', 'LoadAds', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadAds',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyEnd', 1734359006621);
#         }
#     })</script><script>if(typeof uex === 'function'){ uex('ld', 'LoadAds', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadAds',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToLoaded', 1734359006621);
#         }
#     })</script><script>if(typeof uet === 'function'){ uet('bb', 'LoadStyledComponents', {wb: 1}); }</script><script>window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadStyledComponents',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1734359006621);
#         }
#     })</script><style data-styled="" data-styled-version="6.1.0">.dQVJPm{margin:0 1rem;margin:0 var(--ipt-pageMargin, 1rem);}/*!sc*/
# data-styled.g26[id="sc-f65f65be-0"]{content:"dQVJPm,"}/*!sc*/
# .gXsjS{padding:0;}/*!sc*/
# data-styled.g29[id="sc-7f6ccab6-0"]{content:"gXsjS,"}/*!sc*/
# .kbttwV{margin-left:var(--ipt-pageMargin, 1rem);margin-right:var(--ipt-pageMargin, 1rem);margin-bottom:1.5rem;}/*!sc*/
# data-styled.g30[id="sc-7f6ccab6-1"]{content:"kbttwV,"}/*!sc*/
# .bEHzOm{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin-right:1.25rem;}/*!sc*/
# data-styled.g31[id="sc-7f6ccab6-2"]{content:"bEHzOm,"}/*!sc*/
# .emchDx{margin-bottom:0.625rem;}/*!sc*/
# data-styled.g32[id="sc-7f6ccab6-3"]{content:"emchDx,"}/*!sc*/
# .gksDMa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g33[id="sc-7f6ccab6-4"]{content:"gksDMa,"}/*!sc*/
# .ehgMQe{line-height:1.25rem;margin-bottom:1rem;}/*!sc*/
# data-styled.g34[id="sc-7f6ccab6-5"]{content:"ehgMQe,"}/*!sc*/
# .fxFTym{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin:1.5rem var(--ipt-pageMargin, 1rem) 1rem var(--ipt-pageMargin, 1rem);}/*!sc*/
# data-styled.g36[id="sc-f7acd473-1"]{content:"fxFTym,"}/*!sc*/
# @media screen and (min-width: 1280px){.dqQaSD.only-button{width:24.75rem;}}/*!sc*/
# @media screen and (min-width: 1024px) and (max-width: 1279px){.dqQaSD.only-button{width:20rem;}}/*!sc*/
# @media screen and (max-width: 1024px){.dqQaSD.only-button{width:18.25rem;}}/*!sc*/
# @media screen and (max-width: 479px){.dqQaSD.only-button{width:100%;}}/*!sc*/
# @media screen and (min-width: 1280px){.dqQaSD.first-button{margin-right:var(--ipt-pageMargin, 1rem);}}/*!sc*/
# @media screen and (min-width: 1024px) and (max-width: 1279px){.dqQaSD.first-button{margin-right:1rem;}}/*!sc*/
# @media screen and (max-width: 1024px){.dqQaSD.first-button{margin-right:.75rem;}}/*!sc*/
# data-styled.g37[id="sc-f7acd473-2"]{content:"dqQaSD,"}/*!sc*/
# .elKCjC{width:100%;position:relative;}/*!sc*/
# .elKCjC.height-page{height:50vh;}/*!sc*/
# .elKCjC.height-feature{height:20rem;}/*!sc*/
# data-styled.g86[id="sc-b6f25f39-0"]{content:"elKCjC,"}/*!sc*/
# .dzGgcc{margin:auto;position:absolute;top:0;right:0;bottom:0;left:0;}/*!sc*/
# data-styled.g87[id="sc-b6f25f39-1"]{content:"dzGgcc,"}/*!sc*/
# @media screen and (min-width: 1024px){.dPDxhU{display:none;}}/*!sc*/
# data-styled.g127[id="sc-36914dfb-0"]{content:"dPDxhU,"}/*!sc*/
# .evjZJT{display:none;}/*!sc*/
# @media screen and (min-width: 1024px){.evjZJT{display:block;}}/*!sc*/
# data-styled.g128[id="sc-36914dfb-1"]{content:"evjZJT,"}/*!sc*/
# .clAfkS{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}/*!sc*/
# @media screen and (min-width: 1024px) and (max-width: 1279px){.clAfkS{padding-left:.5rem;}}/*!sc*/
# @media screen and (min-width: 1280px){.clAfkS{padding-left:.75rem;}}/*!sc*/
# @media screen and (max-width: 1024px){.clAfkS{padding-top:var(--ipc-pageSection-bottomMargin);}}/*!sc*/
# data-styled.g170[id="sc-f2e21260-0"]{content:"clAfkS,"}/*!sc*/
# .UenMT{min-height:50vh;overflow-x:clip;position:relative;}/*!sc*/
# data-styled.g171[id="sc-65d2a03-0"]{content:"UenMT,"}/*!sc*/
# .hLElui{position:relative;}/*!sc*/
# data-styled.g172[id="sc-65d2a03-1"]{content:"hLElui,"}/*!sc*/
# .foEuCN{height:100%;margin:0 0 var(--ipc-pageSection-bottomMargin);padding:1.5rem 0;}/*!sc*/
# data-styled.g173[id="sc-65d2a03-2"]{content:"foEuCN,"}/*!sc*/
# .bBmMwE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;gap:3rem;height:100%;padding-top:.5rem;position:relative;}/*!sc*/
# .bBmMwE .sidebar-intersection{margin-bottom:-3rem;}/*!sc*/
# data-styled.g174[id="sc-65d2a03-3"]{content:"bBmMwE,"}/*!sc*/
# .ftQRpc .all-topics-prompt__panel{padding:0;max-width:calc(700px - 2rem);}/*!sc*/
# data-styled.g175[id="sc-d7f58ed4-0"]{content:"ftQRpc,"}/*!sc*/
# .hJXYmZ{color:rgb(0,0,0);z-index:5;}/*!sc*/
# .hJXYmZ:hover,.hJXYmZ:active,.hJXYmZ:focus{color:rgb(0,0,0);}/*!sc*/
# data-styled.g272[id="sc-87e28572-0"]{content:"hJXYmZ,"}/*!sc*/
# .jJgJDZ{width:40px;-webkit-align-self:center;-ms-flex-item-align:center;-ms-grid-row-align:center;align-self:center;}/*!sc*/
# .jJgJDZ .st0{fill-rule:evenodd;-webkit-clip-rule:evenodd;clip-rule:evenodd;fill:#FFFFFF;}/*!sc*/
# .jJgJDZ .st1{fill-rule:evenodd;-webkit-clip-rule:evenodd;clip-rule:evenodd;fill:#0066FF;}/*!sc*/
# .jJgJDZ .st2{fill:#FFFFFF;}/*!sc*/
# .jJgJDZ .st3{fill:#0066FF;}/*!sc*/
# data-styled.g273[id="sc-ksltVi"]{content:"jJgJDZ,"}/*!sc*/
# .jwNagF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g274[id="sc-hBMVwJ"]{content:"jwNagF,"}/*!sc*/
# .kkBjoD{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g275[id="sc-fnVZQs"]{content:"kkBjoD,"}/*!sc*/
# .lhwAcH{background:none;display:none;-ms-grid-columns:1fr 1fr;grid-template-columns:1fr 1fr;-ms-grid-gap:1rem;grid-gap:1rem;padding-bottom:1rem;width:80%;margin:0 auto;}/*!sc*/
# @media screen and (min-width: 1024px){.lhwAcH{display:-ms-grid;display:grid;}}/*!sc*/
# data-styled.g276[id="sc-fFSPgy"]{content:"lhwAcH,"}/*!sc*/
# .iSbCYR{border-color:rgb(31,31,31);border-color:var(--ipt-baseAlt-shade1-color, rgb(31,31,31));border-width:2px;border-style:solid;border-radius:10px;padding-top:1rem;}/*!sc*/
# data-styled.g277[id="sc-bkbjWr"]{content:"iSbCYR,"}/*!sc*/
# .eCMsXs{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:1.25rem;font-size:var(--ipt-type-headline6-size, 1.25rem);font-weight:600;font-weight:var(--ipt-type-headline6-weight, 600);-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;letter-spacing:.0125em;letter-spacing:var(--ipt-type-headline6-letterSpacing, .0125em);line-height:1.5rem;line-height:var(--ipt-type-headline6-lineHeight, 1.5rem);text-transform:none;text-transform:var(--ipt-type-headline6-textTransform, none);text-align:center;}/*!sc*/
# data-styled.g278[id="sc-iemXqs"]{content:"eCMsXs,"}/*!sc*/
# .gfQScs{border-color:rgb(31,31,31);border-color:var(--ipt-baseAlt-shade1-color, rgb(31,31,31));border-width:2px;border-style:solid;border-radius:10px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;line-height:2rem;}/*!sc*/
# data-styled.g279[id="sc-dIvsgl"]{content:"gfQScs,"}/*!sc*/
# .kzFcVd{margin-top:1.5rem;padding-left:1.5rem;text-align:left;}/*!sc*/
# data-styled.g280[id="sc-hHEhDq"]{content:"kzFcVd,"}/*!sc*/
# .hICUSh{color:rgba(var(--ipt-on-baseAlt-rgb), .7);}/*!sc*/
# data-styled.g281[id="sc-dlMCtj"]{content:"hICUSh,"}/*!sc*/
# .jjNfXQ{margin:1rem 1.5rem 1rem auto;}/*!sc*/
# data-styled.g282[id="sc-kfYpNk"]{content:"jjNfXQ,"}/*!sc*/
# .gbBxAC{border-width:4px;border-style:solid;border-color:rgb(255,255,255);border-color:var(--ipt-on-baseAlt-color, rgb(255,255,255));border-radius:4px;border-radius:var(--ipt-cornerRadius, 4px);vertical-align:middle;}/*!sc*/
# data-styled.g283[id="sc-fKgKDd"]{content:"gbBxAC,"}/*!sc*/
# .cvdsgD{--ipt-base-rgb:255,255,255;--ipt-base-bg:rgb(255,255,255);--ipt-base-color:rgb(255,255,255);--ipt-base-shade1-rgb:250,250,250;--ipt-base-shade1-bg:rgb(250,250,250);--ipt-base-shade1-color:rgb(250,250,250);--ipt-base-shade2-rgb:240,240,240;--ipt-base-shade2-bg:rgb(240,240,240);--ipt-base-shade2-color:rgb(240,240,240);--ipt-base-shade3-rgb:255,255,255;--ipt-base-shade3-bg:rgb(255,255,255);--ipt-base-shade3-color:rgb(255,255,255);--ipt-on-base-rgb:0,0,0;--ipt-on-base-color:rgb(0,0,0);--ipt-on-base-accent1-rgb:245,197,24;--ipt-on-base-accent1-color:rgb(245,197,24);--ipt-on-base-accent2-rgb:14,99,190;--ipt-on-base-accent2-color:rgb(14,99,190);--ipt-on-base-accent3-rgb:189,36,4;--ipt-on-base-accent3-color:rgb(189,36,4);--ipt-on-base-accent4-rgb:0,138,0;--ipt-on-base-accent4-color:rgb(0,138,0);--ipt-on-base-textPrimary-opacity:0.87;--ipt-on-base-textPrimary-color:rgba(0,0,0,0.87);--ipt-on-base-textSecondary-opacity:0.54;--ipt-on-base-textSecondary-color:rgba(0,0,0,0.54);--ipt-on-base-textHint-opacity:0.38;--ipt-on-base-textHint-color:rgba(0,0,0,0.38);--ipt-on-base-textDisabled-opacity:0.38;--ipt-on-base-textDisabled-color:rgba(0,0,0,0.38);--ipt-on-base-textIcon-opacity:0.5;--ipt-on-base-textIcon-color:rgba(0,0,0,0.5);--ipt-base-border-opacity:0.12;--ipt-base-hover-opacity:0.08;--ipt-base-pressed-opacity:0.16;--ipt-base-stripes-opacity:0.04;--ipt-base-border-color:rgba(0,0,0,0.12);--ipt-base-hover-color:rgba(0,0,0,0.08);--ipt-base-pressed-color:rgba(0,0,0,0.16);--ipt-base-stripes-color:rgba(0,0,0,0.04);--ipt-baseAlt-rgb:0,0,0;--ipt-baseAlt-bg:rgb(0,0,0);--ipt-baseAlt-color:rgb(0,0,0);--ipt-baseAlt-shade1-rgb:31,31,31;--ipt-baseAlt-shade1-bg:rgb(31,31,31);--ipt-baseAlt-shade1-color:rgb(31,31,31);--ipt-baseAlt-shade2-rgb:26,26,26;--ipt-baseAlt-shade2-bg:rgb(26,26,26);--ipt-baseAlt-shade2-color:rgb(26,26,26);--ipt-baseAlt-shade3-rgb:18,18,18;--ipt-baseAlt-shade3-bg:rgb(18,18,18);--ipt-baseAlt-shade3-color:rgb(18,18,18);--ipt-on-baseAlt-rgb:255,255,255;--ipt-on-baseAlt-color:rgb(255,255,255);--ipt-on-baseAlt-accent1-rgb:245,197,24;--ipt-on-baseAlt-accent1-color:rgb(245,197,24);--ipt-on-baseAlt-accent2-rgb:87,153,239;--ipt-on-baseAlt-accent2-color:rgb(87,153,239);--ipt-on-baseAlt-accent3-rgb:251,60,60;--ipt-on-baseAlt-accent3-color:rgb(251,60,60);--ipt-on-baseAlt-accent4-rgb:103,173,75;--ipt-on-baseAlt-accent4-color:rgb(103,173,75);--ipt-on-baseAlt-textPrimary-opacity:1;--ipt-on-baseAlt-textPrimary-color:rgba(255,255,255,1);--ipt-on-baseAlt-textSecondary-opacity:0.7;--ipt-on-baseAlt-textSecondary-color:rgba(255,255,255,0.7);--ipt-on-baseAlt-textHint-opacity:0.5;--ipt-on-baseAlt-textHint-color:rgba(255,255,255,0.5);--ipt-on-baseAlt-textDisabled-opacity:0.5;--ipt-on-baseAlt-textDisabled-color:rgba(255,255,255,0.5);--ipt-on-baseAlt-textIcon-opacity:1;--ipt-on-baseAlt-textIcon-color:rgba(255,255,255,1);--ipt-baseAlt-border-opacity:0.2;--ipt-baseAlt-hover-opacity:0.08;--ipt-baseAlt-pressed-opacity:0.32;--ipt-baseAlt-stripes-opacity:0.12;--ipt-baseAlt-border-color:rgba(255,255,255,0.2);--ipt-baseAlt-hover-color:rgba(255,255,255,0.08);--ipt-baseAlt-pressed-color:rgba(255,255,255,0.32);--ipt-baseAlt-stripes-color:rgba(255,255,255,0.12);--ipt-accent1-rgb:245,197,24;--ipt-accent1-bg:rgb(245,197,24);--ipt-accent1-color:rgb(245,197,24);--ipt-on-accent1-rgb:0,0,0;--ipt-on-accent1-color:rgb(0,0,0);--ipt-accent2-rgb:14,99,190;--ipt-accent2-bg:rgb(14,99,190);--ipt-accent2-color:rgb(14,99,190);--ipt-on-accent2-rgb:255,255,255;--ipt-on-accent2-color:rgb(255,255,255);--ipt-accent3-rgb:189,36,4;--ipt-accent3-bg:rgb(189,36,4);--ipt-accent3-color:rgb(189,36,4);--ipt-on-accent3-rgb:255,255,255;--ipt-on-accent3-color:rgb(255,255,255);--ipt-accent4-rgb:0,114,7;--ipt-accent4-bg:rgb(0,114,7);--ipt-accent4-color:rgb(0,114,7);--ipt-on-accent4-rgb:255,255,255;--ipt-on-accent4-color:rgb(255,255,255);--ipc-pageSection-bottomMargin:.75rem;--ipc-pageSection-base-bg:rgb(250,250,250);--ipc-pageSection-base-rgb:250,250,250;--ipc-pageSection-baseAlt-bg:rgb(18,18,18);-- ...
# .cvdsgD .footer__app{background:rgba(255,255,255, .1);background:rgba(var(--ipt-on-baseAlt-rgb), .1);margin-bottom:.5rem;padding:1rem 0;}/*!sc*/
# .cvdsgD .footer__socials{margin:16px 0;}/*!sc*/
# .cvdsgD .footer__logo{min-height:40px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:16px;}/*!sc*/
# .cvdsgD .footer__copyright{color:rgba(255,255,255,0.7);color:var(--ipt-on-baseAlt-textSecondary-color, rgba(255,255,255,0.7));font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:.75rem;font-size:var(--ipt-type-copyright-size, .75rem);font-weight:400;font-weight:var(--ipt-type-copyright-weight, 400);letter-spacing:.03333em;letter-spacing:var(--ipt-type-copyright-letterSpacing, .03333em);line-height:1rem;line-height:var(--ipt-type-copyright-lineHeight, 1rem);text-transform:none;text-transform:var(--ipt-type-copyright-textTransform, none);margin:.5em 0;}/*!sc*/
# .cvdsgD .footer__links{max-width:360px;}/*!sc*/
# .cvdsgD .footer__linksRow{display:inline;}/*!sc*/
# .cvdsgD .footer__linksRow li{margin-left:0.5rem;margin-right:0.5rem;}/*!sc*/
# .cvdsgD .footerLink--wideScreen{display:none;}/*!sc*/
# @media screen and (min-width: 600px){.cvdsgD{margin-top:0;}.cvdsgD .footer__links{max-width:600px;}.cvdsgD .footer__linksRow{display:inline;}}/*!sc*/
# .cvdsgD .footer__sign-in-button{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .cvdsgD .footer__sign-in-mobile-button{display:none;}/*!sc*/
# @media screen and (max-width: 1024px){.cvdsgD .footer__app{margin:0;}.cvdsgD .footer__sign-in{background:rgba(
#                 255,255,255,
#                 0.06
#             );padding:1rem 0;}.cvdsgD .footer__sign-in-button{display:none;}.cvdsgD .footer__sign-in-mobile-button{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# @media screen and (min-width: 1024px){.cvdsgD .footer__links{max-width:1024px;}.cvdsgD .footer__app{display:none;}.cvdsgD .footer__socials{display:none;}.cvdsgD .footerLink--wideScreen{display:inline-block;}.cvdsgD .footerLink--smallScreen{display:none;}.cvdsgD .footer__sign-in{background:rgb(0,0,0);background:var(--ipt-baseAlt-bg, rgb(0,0,0));padding:0;}.cvdsgD .footer__sign-in-button{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}.cvdsgD .footer__sign-in-mobile-button{display:none;}}/*!sc*/
# data-styled.g284[id="sc-bCwene"]{content:"cvdsgD,"}/*!sc*/
# .fWrebE{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;margin-left:0.25rem;margin-right:auto;-webkit-order:1;-ms-flex-order:1;order:1;position:relative;}/*!sc*/
# @media screen and (min-width: 1024px){.fWrebE{margin-left:auto;margin-right:0.5rem;-webkit-order:0;-ms-flex-order:0;order:0;padding-left:0;}}/*!sc*/
# @media (hover: hover) and (pointer: fine){.fWrebE:focus{outline:1px dashed currentColor;}.fWrebE:focus:active{outline:0;}.fWrebE:before,.fWrebE:after{border-radius:10%;bottom:0;content:'';height:100%;left:0;margin:auto;opacity:0;position:absolute;right:0;top:0;-webkit-transition:opacity 0.2s cubic-bezier(1, 1, 1, 1);transition:opacity 0.2s cubic-bezier(1, 1, 1, 1);width:100%;background:rgb(0,0,0);background:var(--ipt-on-accent1-color, rgb(0,0,0));}.fWrebE:hover:before{opacity:0.08;opacity:var(--ipt-base-hover-opacity, 0.08);}.fWrebE:active:after{opacity:0.16;opacity:var(--ipt-base-pressed-opacity, 0.16);}}/*!sc*/
# data-styled.g328[id="sc-iwaiBT"]{content:"fWrebE,"}/*!sc*/
# .hFkzpy{background:rgb(31,31,31);background:var(--ipt-baseAlt-shade1-bg, rgb(31,31,31));width:100%;left:0;right:0;top:100%;position:absolute;}/*!sc*/
# @media screen and (min-width: 600px){.hFkzpy{border-radius:4px;border-radius:var(--ipt-cornerRadius, 4px);top:calc(100% + 0.25rem);}}/*!sc*/
# .hFkzpy ul{margin:0;padding:0;list-style:none;}/*!sc*/
# .hFkzpy ul li{display:inline;}/*!sc*/
# .hFkzpy .anim-enter{opacity:0;}/*!sc*/
# .hFkzpy .anim-enter-active{opacity:1;-webkit-transition:opacity 200ms;transition:opacity 200ms;}/*!sc*/
# .hFkzpy .anim-exit{opacity:1;}/*!sc*/
# .hFkzpy .anim-exit-active{opacity:0;-webkit-transition:opacity 200ms;transition:opacity 200ms;}/*!sc*/
# data-styled.g329[id="sc-cxNGUP"]{content:"hFkzpy,"}/*!sc*/
# .gvNtUq li:first-child>.searchResult{border-top:none;}/*!sc*/
# .gvNtUq .searchTypeahead__input{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:1rem;font-size:var(--ipt-type-body-size, 1rem);font-weight:400;font-weight:var(--ipt-type-body-weight, 400);letter-spacing:.03125em;letter-spacing:var(--ipt-type-body-letterSpacing, .03125em);line-height:1.5rem;line-height:var(--ipt-type-body-lineHeight, 1.5rem);text-transform:none;text-transform:var(--ipt-type-body-textTransform, none);color:rgb(255,255,255);color:var(--ipt-on-baseAlt-color, rgb(255,255,255));caret-color:rgb(255,255,255);caret-color:var(--ipt-on-baseAlt-color, rgb(255,255,255));}/*!sc*/
# .gvNtUq .searchTypeahead__input:placeholder{color:rgba(255,255,255,0.5);color:var(--ipt-on-baseAlt-textHint-color, rgba(255,255,255,0.5));}/*!sc*/
# @media screen and (min-width: 600px){.gvNtUq .searchTypeahead__input{font-family:'Roboto','Helvetica','Arial',sans-serif;font-family:var(--ipt-font-family);font-size:.875rem;font-size:var(--ipt-type-bodySmall-size, .875rem);font-weight:400;font-weight:var(--ipt-type-bodySmall-weight, 400);letter-spacing:.01786em;letter-spacing:var(--ipt-type-bodySmall-letterSpacing, .01786em);line-height:1.25rem;line-height:var(--ipt-type-bodySmall-lineHeight, 1.25rem);text-transform:none;text-transform:var(--ipt-type-bodySmall-textTransform, none);color:rgba(0,0,0,0.87);color:var(--ipt-on-base-textPrimary-color, rgba(0,0,0,0.87));caret-color:rgba(0,0,0,0.54);caret-color:var(--ipt-on-base-textSecondary-color, rgba(0,0,0,0.54));}}/*!sc*/
# data-styled.g334[id="sc-bYwyHq"]{content:"gvNtUq,"}/*!sc*/
# .jCLhco{position:relative;}/*!sc*/
# .jCLhco .searchCatSelector-menu{top:100%;position:absolute;margin-top:0.25rem;}/*!sc*/
# .jCLhco .searchCatSelector .searchCatSelector__item{-webkit-transition:color 0.15s;transition:color 0.15s;cursor:poiner;}/*!sc*/
# .jCLhco .searchCatSelector .searchCatSelector__item .searchCatSelector__itemIcon{margin-right:0.75rem;opacity:0.5;-webkit-transition:opacity 0.2s;transition:opacity 0.2s;}/*!sc*/
# .jCLhco .searchCatSelector .searchCatSelector__item:hover .searchCatSelector__itemIcon,.jCLhco .searchCatSelector .searchCatSelector__item:focus .searchCatSelector__itemIcon,.jCLhco .searchCatSelector .searchCatSelector__item.searchCatSelector__itemSelected .searchCatSelector__itemIcon{opacity:1;}/*!sc*/
# .jCLhco .searchCatSelector .searchCatSelector__item.searchCatSelector__itemSelected{color:rgb(245,197,24);color:var(--ipt-on-base-accent1-color, rgb(245,197,24));}/*!sc*/
# data-styled.g336[id="sc-iklJRA"]{content:"jCLhco,"}/*!sc*/
# @media screen and (min-width: 480px){.sc-jJMFAr{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# @media screen and (max-width: 600px){.sc-jJMFAr{display:none;}}/*!sc*/
# data-styled.g337[id="sc-jJMFAr"]{content:"dCFFsI,"}/*!sc*/
# @media screen and (min-width: 480px){.sc-hiKeQa{display:none;}}/*!sc*/
# @media screen and (max-width: 600px){.sc-hiKeQa{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}}/*!sc*/
# data-styled.g338[id="sc-hiKeQa"]{content:"biLEWD,"}/*!sc*/
# .jgYgxX{position:relative;}/*!sc*/
# .jgYgxX.jgYgxX.searchCatSelector-menuWrapper .searchCatSelector-menu{left:0;right:auto;}/*!sc*/
# .jgYgxX .searchCatSelector-button{display:none;}/*!sc*/
# .jgYgxX .searchCatSelector__opener{border-radius:2px 0 0 2px;padding:0 0.25rem 0 0.75rem;min-height:32px;height:20px;border-right:1px solid rgba(0, 0, 0, 0.3);}/*!sc*/
# .jgYgxX .searchCatSelector__opener svg{margin:0;}/*!sc*/
# .jgYgxX.searchCatSelector-all-breakpoints .searchCatSelector-button{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .jgYgxX .searchCatSelector-button-post-icon{-webkit-transition:-webkit-transform 0.2s;transition:transform 0.2s;-webkit-transform:rotateX(0);-moz-transform:rotateX(0);-ms-transform:rotateX(0);transform:rotateX(0);}/*!sc*/
# .jgYgxX.searchCatSelector-isVisible .searchCatSelector-button-post-icon{-webkit-transform:rotateX(180deg);-moz-transform:rotateX(180deg);-ms-transform:rotateX(180deg);transform:rotateX(180deg);}/*!sc*/
# data-styled.g339[id="sc-gXfWyg"]{content:"jgYgxX,"}/*!sc*/
# .kpMrHS{background:rgb(31,31,31);background:var(--ipt-baseAlt-shade1-bg, rgb(31,31,31));display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin:0;padding:0;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media screen and (min-width: 600px){.kpMrHS.searchform--focused .searchform__submit{background:transparent;opacity:1;}}/*!sc*/
# @media screen and (min-width: 600px){.kpMrHS{-webkit-transition:border 0.2s,background-color 0.2s,box-shadow 0.2s;transition:border 0.2s,background-color 0.2s,box-shadow 0.2s;background:rgb(255,255,255);background:var(--ipt-base-bg, rgb(255,255,255));border-radius:4px;border-radius:var(--ipt-cornerRadius, 4px);}.kpMrHS.searchform--focused{background:rgb(255,255,255);background:var(--ipt-base-bg, rgb(255,255,255));outline:none;border-color:none;box-shadow:inset 0 0 0 2px rgb(245,197,24);box-shadow:inset 0 0 0 2px var(--ipt-accent1-color, rgb(245,197,24));}}/*!sc*/
# .kpMrHS .searchform__inputContainer{width:100%;padding-right:3.5rem;}/*!sc*/
# .kpMrHS .searchform__submit{background:rgb(250,250,250);background:var(--ipt-base-shade1-bg, rgb(250,250,250));color:rgba(0,0,0,0.54);color:var(--ipt-on-base-textSecondary-color, rgba(0,0,0,0.54));border-radius:4px;border-radius:var(--ipt-cornerRadius, 4px);position:absolute;right:0.35rem;min-width:2rem;cursor:pointer;top:0.35rem;-webkit-transition:all 0.2s;transition:all 0.2s;}/*!sc*/
# @media screen and (min-width: 600px){.kpMrHS .searchform__submit{background:rgb(255,255,255);background:var(--ipt-base-bg, rgb(255,255,255));}}/*!sc*/
# .kpMrHS .imdb-header-search__input{background:transparent;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;outline:none;padding:1rem 1rem 1rem 0.75rem;width:100%;}/*!sc*/
# @media screen and (min-width: 600px){.kpMrHS .imdb-header-search__input{padding:0.375em 0 0.375rem 0.5rem;}}/*!sc*/
# .kpMrHS .imdb-header-search__input ::-ms-clear{display:none;}/*!sc*/
# data-styled.g340[id="sc-cBornZ"]{content:"kpMrHS,"}/*!sc*/
# .gmVJgP{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:0;margin:0;min-height:3.5rem;opacity:0;-webkit-transform:translateY(-10px);-moz-transform:translateY(-10px);-ms-transform:translateY(-10px);transform:translateY(-10px);-webkit-transition:none;transition:none;-webkit-order:3;-ms-flex-order:3;order:3;pointer-events:none;position:absolute;top:0;visibility:hidden;width:100%;z-index:1;}/*!sc*/
# .gmVJgP .imdb-header-search__state-closer{-webkit-transform:scale(0.5);-moz-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);-webkit-transition:-webkit-transform 0.2s 0.1s;transition:transform 0.2s 0.1s;display:inline;margin:0.25rem;position:absolute;right:0;top:0;}/*!sc*/
# .gmVJgP .imdb-header-search__state,.gmVJgP .imdb-header-search__input,.gmVJgP .nav-search__search-submit{-moz-appearance:none;-webkit-appearance:none;-webkit-appearance:none;-moz-appearance:none;-ms-appearance:none;appearance:none;border:none;}/*!sc*/
# @media screen and (min-width: 600px){.gmVJgP{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin:0 0.5rem;padding:0;min-height:2.25rem;-webkit-order:3;-ms-flex-order:3;order:3;opacity:1;visibility:visible;pointer-events:auto;position:relative;-webkit-transform:translateY(0);-moz-transform:translateY(0);-ms-transform:translateY(0);transform:translateY(0);}.gmVJgP .imdb-header-search__state,.gmVJgP .nav-search__search-submit{padding:0;}.gmVJgP .nav-search__search-submit:focus{outline:var(--ipt-focus-outline-on-base);outline-offset:1px;}.gmVJgP .imdb-header-search__state-closer{display:none;}}/*!sc*/
# data-styled.g341[id="sc-ciSkmu"]{content:"gmVJgP,"}/*!sc*/
# .hujVkB{-webkit-transition:all 0.3s;transition:all 0.3s;opacity:1;-webkit-transform:scale(1);-moz-transform:scale(1);-ms-transform:scale(1);transform:scale(1);padding:0;margin-left:1rem;-webkit-order:3;-ms-flex-order:3;order:3;}/*!sc*/
# @media screen and (min-width: 600px){.hujVkB{-webkit-order:3;-ms-flex-order:3;order:3;}.hujVkB.imdb-header-search__state-opener{display:none;}}/*!sc*/
# data-styled.g342[id="sc-jcwoBj"]{content:"hujVkB,"}/*!sc*/
# .gDLKjF:checked~.nav-search__search-container{background-color:rgb(0,0,0);background-color:var(--ipt-baseAlt-color, rgb(0,0,0));opacity:1;-webkit-transform:scale(1);-moz-transform:scale(1);-ms-transform:scale(1);transform:scale(1);-webkit-transition:opacity 0.2s,-webkit-transform 0.2s;transition:opacity 0.2s,transform 0.2s;visibility:visible;pointer-events:auto;z-index:100;}/*!sc*/
# .gDLKjF:checked~.nav-search__search-container .nav-search__search-select,.gDLKjF:checked~.nav-search__search-container .nav-search__search-submit{display:none;}/*!sc*/
# .gDLKjF:checked~.nav-search__search-container .imdb-header-search__state-closer{-webkit-transform:scale(1);-moz-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}/*!sc*/
# .gDLKjF:checked~.nav-search__search-container~.sc-jcwoBj{-webkit-transform:scale(0.5);-moz-transform:scale(0.5);-ms-transform:scale(0.5);transform:scale(0.5);-webkit-transition:all 0.3s 0.3s;transition:all 0.3s 0.3s;opacity:0;}/*!sc*/
# data-styled.g343[id="sc-carGes"]{content:"gDLKjF,"}/*!sc*/
# body.drawer-bodyLocked{overflow:hidden;position:relative;}/*!sc*/
# data-styled.g344[id="sc-global-kcltSs1"]{content:"sc-global-kcltSs1,"}/*!sc*/
# .gUPgwv.drawer{bottom:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;left:0;overflow:hidden;perspective:70vh;pointer-events:none;position:fixed;right:0;top:0;visibility:hidden;z-index:100;}/*!sc*/
# .gUPgwv .drawer__panel{background:rgb(31,31,31);background:var(--ipt-baseAlt-shade1-bg, rgb(31,31,31));box-shadow:none;box-sizing:border-box;height:100%;overflow-x:hidden;overflow-y:auto;position:relative;-webkit-transform:translateX(calc(-100% - 36px));-moz-transform:translateX(calc(-100% - 36px));-ms-transform:translateX(calc(-100% - 36px));transform:translateX(calc(-100% - 36px));transform-origin:right center;-webkit-transition:all 0.3s,box-shadow 0s;transition:all 0.3s,box-shadow 0s;width:280px;z-index:2;-webkit-overflow-scroll:touch;}/*!sc*/
# ...
# e)?h=d-1:D.pop();D.push(c)}C=H.now()-F;s=Math.min(s,C);v=Math.max(v,C);A=(A*b+C)/(b+1);b+=1;q({k:x,e:D,min:Math.floor(1E3*s),max:Math.floor(1E3*v),avg:Math.floor(1E3*A)},{c:1});u=[];D=[];h=0}}var f=100,B=20,z=25,x="mmm1",l,k,d=a.window,e=d.document,w=d.setInterval,t=a.ue,q=a.ue_cel.log,g,s=1E3,v=0,A=0,b=0,F,C,u=[],D=[],h=0,p,y,E,G,r,H=m&&m.now&&m||Date.now&&Date||{now:function(){return(new Date).getTime()}};return{on:function(a){l=a.ts;k=a.ns;t.attach&&t.attach("mousemove",n,e);g=w(c,3E3)},off:function(a){k&&
# (p&&n(p,!0),c());clearInterval(g);t.detach&&t.detach("mousemove",n,e)},ready:function(){return a.ue_cel&&a.ue_cel.log},reset:function(){u=[];D=[];h=0;p=null}}}(window.performance),a.ue_cel&&a.ue_cel.registerModule("mouse move module",a.ue_mmm))})(ue_csm);
#
#
#
#
# ue_csm.ue_unrt = 1500;
# (function(d,b,t){function u(a,g){var c=a.srcElement||a.target||{},b={k:v,t:g.t,dt:g.dt,x:a.pageX,y:a.pageY,p:e.getXPath(c),n:c.nodeName};a.button&&(b.b=a.button);c.type&&(b.ty=c.type);c.href&&(b.r=e.extractStringValue(c.href));c.id&&(b.i=c.id);c.className&&c.className.split&&(b.c=c.className.split(/\s+/));h+=1;e.getFirstAscendingWidget(c,function(a){b.wd=a;d.ue.log(b,r)})}function w(a){if(!x(a.srcElement||a.target)){m+=1;n=!0;var g=f=d.ue.d(),c;p&&"function"===typeof p.now&&a.timeStamp&&(c=p.now()-
# a.timeStamp,c=parseFloat(c.toFixed(2)));s=b.setTimeout(function(){u(a,{t:g,dt:c})},y)}}function z(a){if(a){var b=a.filter(A);a.length!==b.length&&(q=!0,k=d.ue.d(),n&&q&&(k&&f&&d.ue.log({k:B,t:f,m:Math.abs(k-f)},r),l(),q=!1,k=0))}}function A(a){if(!a)return!1;var b="characterData"===a.type?a.target.parentElement:a.target;if(!b||!b.hasAttributes||!b.attributes)return!1;var c={"class":"gw-clock gw-clock-aria s-item-container-height-auto feed-carousel using-mouse kfs-inner-container".split(" "),id:["dealClock",
# "deal_expiry_timer","timer"],role:["timer"]},d=!1;Object.keys(c).forEach(function(a){var e=b.attributes[a]?b.attributes[a].value:"";(c[a]||"").forEach(function(a){-1!==e.indexOf(a)&&(d=!0)})});return d}function x(a){if(!a)return!1;var b=(e.extractStringValue(a.nodeName)||"").toLowerCase(),c=(e.extractStringValue(a.type)||"").toLowerCase(),d=(e.extractStringValue(a.href)||"").toLowerCase();a=(e.extractStringValue(a.id)||"").toLowerCase();var f="checkbox color date datetime-local email file month number password radio range reset search tel text time url week".split(" ");
# if(-1!==["select","textarea","html"].indexOf(b)||"input"===b&&-1!==f.indexOf(c)||"a"===b&&-1!==d.indexOf("http")||-1!==["sitbreaderrightpageturner","sitbreaderleftpageturner","sitbreaderpagecontainer"].indexOf(a))return!0}function l(){n=!1;f=0;b.clearTimeout(s)}function C(){b.ue.onunload(function(){ue.count("armored-cxguardrails.unresponsive-clicks.violations",h);ue.count("armored-cxguardrails.unresponsive-clicks.violationRate",h/m*100||0)})}if(b.MutationObserver&&b.addEventListener&&Object.keys&&
# d&&d.ue&&d.ue.log&&d.ue_unrt&&d.ue_utils){var y=d.ue_unrt,r="cel",v="unr_mcm",B="res_mcm",p=b.performance,e=d.ue_utils,n=!1,f=0,s=0,q=!1,k=0,h=0,m=0;b.addEventListener&&(b.addEventListener("mousedown",w,!0),b.addEventListener("beforeunload",l,!0),b.addEventListener("visibilitychange",l,!0),b.addEventListener("pagehide",l,!0));b.ue&&b.ue.event&&b.ue.onSushiUnload&&b.ue.onunload&&C();(new MutationObserver(z)).observe(t,{childList:!0,attributes:!0,characterData:!0,subtree:!0})}})(ue_csm,window,document);
#
#
# ue_csm.ue.exec(function(g,e){if(e.ue_err){var f="";e.ue_err.errorHandlers||(e.ue_err.errorHandlers=[]);e.ue_err.errorHandlers.push({name:"fctx",handler:function(a){if(!a.logLevel||"FATAL"===a.logLevel)if(f=g.getElementsByTagName("html")[0].innerHTML){var b=f.indexOf("var ue_t0=ue_t0||+new Date();");if(-1!==b){var b=f.substr(0,b).split(String.fromCharCode(10)),d=Math.max(b.length-10-1,0),b=b.slice(d,b.length-1);a.fcsmln=d+b.length+1;a.cinfo=a.cinfo||{};for(var c=0;c<b.length;c++)a.cinfo[d+c+1+""]=
# b[c]}b=f.split(String.fromCharCode(10));a.cinfo=a.cinfo||{};if(!(a.f||void 0===a.l||a.l in a.cinfo))for(c=+a.l-1,d=Math.max(c-5,0),c=Math.min(c+5,b.length-1);d<=c;d++)a.cinfo[d+1+""]=b[d]}}})}},"fatals-context")(document,window);
#
#
# (function(m,b){function c(k){function f(a){a&&"string"===typeof a&&(a=(a=a.match(/^(?:https?:)?\/\/(.*?)(\/|$)/i))&&1<a.length?a[1]:null,a&&a&&("number"===typeof e[a]?e[a]++:e[a]=1))}function d(a){var e=10,d=+new Date;a&&a.timeRemaining?e=a.timeRemaining():a={timeRemaining:function(){return Math.max(0,e-(+new Date-d))}};for(var c=b.performance.getEntries(),k=e;g<c.length&&k>n;)c[g].name&&f(c[g].name),g++,k=a.timeRemaining();g>=c.length?h(!0):l()}function h(a){if(!a){a=m.scripts;var c;if(a)for(var d=
# 0;d<a.length;d++)(c=a[d].getAttribute("src"))&&"undefined"!==c&&f(c)}0<Object.keys(e).length&&(p&&ue_csm.ue&&ue_csm.ue.event&&(a={domains:e,pageType:b.ue_pty||null,subPageType:b.ue_spty||null,pageTypeId:b.ue_pti||null},ue_csm.ue_sjslob&&(a.lob=ue_csm.ue_lob||"0"),ue_csm.ue.event(a,"csm","csm.CrossOriginDomains.2")),b.ue_ext=e)}function l(){!0===k?d():b.requestIdleCallback?b.requestIdleCallback(d):b.requestAnimationFrame?b.requestAnimationFrame(d):b.setTimeout(d,100)}function c(){if(b.performance&&
# b.performance.getEntries){var a=b.performance.getEntries();!a||0>=a.length?h(!1):l()}else h(!1)}var e=b.ue_ext||{};b.ue_ext||c();return e}function q(){setTimeout(c,r)}var s=b.ue_dserr||!1,p=!0,n=1,r=2E3,g=0;b.ue_err&&s&&(b.ue_err.errorHandlers||(b.ue_err.errorHandlers=[]),b.ue_err.errorHandlers.push({name:"ext",handler:function(b){if(!b.logLevel||"FATAL"===b.logLevel){var f=c(!0),d=[],h;for(h in f){var f=h,g=f.match(/amazon(\.com?)?\.\w{2,3}$/i);g&&1<g.length||-1!==f.indexOf("amazon-adsystem.com")||
# -1!==f.indexOf("amazonpay.com")||-1!==f.indexOf("cloudfront-labs.amazonaws.com")||d.push(h)}b.ext=d}}}));b.ue&&b.ue.isl?c():b.ue&&ue.attach&&ue.attach("load",q)})(document,window);
#
#
#
#
#
# var ue_wtc_c = 3;
# ue_csm.ue.exec(function(b,e){function l(){for(var a=0;a<f.length;a++)a:for(var d=s.replace(A,f[a])+g[f[a]]+t,c=arguments,b=0;b<c.length;b++)try{c[b].send(d);break a}catch(e){}g={};f=[];n=0;k=p}function u(){B?l(q):l(C,q)}function v(a,m,c){r++;if(r>w)d.count&&1==r-w&&(d.count("WeblabTriggerThresholdReached",1),b.ue_int&&console.error("Number of max call reached. Data will no longer be send"));else{var h=c||{};h&&-1<h.constructor.toString().indexOf(D)&&a&&-1<a.constructor.toString().indexOf(x)&&m&&-1<
# m.constructor.toString().indexOf(x)?(h=b.ue_id,c&&c.rid&&(h=c.rid),c=h,a=encodeURIComponent(",wl="+a+"/"+m),2E3>a.length+p?(2E3<k+a.length&&u(),void 0===g[c]&&(g[c]="",f.push(c)),g[c]+=a,k+=a.length,n||(n=e.setTimeout(u,E))):b.ue_int&&console.error("Invalid API call. The input provided is over 2000 chars.")):d.count&&(d.count("WeblabTriggerImproperAPICall",1),b.ue_int&&console.error("Invalid API call. The input provided does not match the API protocol i.e ue.trigger(String, String, Object)."))}}function F(){d.trigger&&
# d.trigger.isStub&&d.trigger.replay(function(a){v.apply(this,a)})}function y(){z||(f.length&&l(q),z=!0)}var t=":1234",s="//"+b.ue_furl+"/1/remote-weblab-triggers/1/OE/"+b.ue_mid+":"+b.ue_sid+":PLCHLDR_RID$s:wl-client-id%3DCSMTriger",A="PLCHLDR_RID",E=b.wtt||1E4,p=s.length+t.length,w=b.mwtc||2E3,G=1===e.ue_wtc_c,B=3===e.ue_wtc_c,H=e.XMLHttpRequest&&"withCredentials"in new e.XMLHttpRequest,x="String",D="Object",d=b.ue,g={},f=[],k=p,n,z=!1,r=0,C=function(){return{send:function(a){if(H){var b=new e.XMLHttpRequest;
# b.open("GET",a,!0);G&&(b.withCredentials=!0);b.send()}else throw"";}}}(),q=function(){return{send:function(a){(new Image).src=a}}}();e.encodeURIComponent&&(d.attach&&(d.attach("beforeunload",y),d.attach("pagehide",y)),F(),d.trigger=v)},"client-wbl-trg")(ue_csm,window);
#
#
# (function(k,d,h){function f(a,c,b){a&&a.indexOf&&0===a.indexOf("http")&&0!==a.indexOf("https")&&l(s,c,a,b)}function g(a,c,b){a&&a.indexOf&&(location.href.split("#")[0]!=a&&null!==a&&"undefined"!==typeof a||l(t,c,a,b))}function l(a,c,b,e){m[b]||(e=u&&e?n(e):"N/A",d.ueLogError&&d.ueLogError({message:a+c+" : "+b,logLevel:v,stack:"N/A"},{attribution:e}),m[b]=1,p++)}function e(a,c){if(a&&c)for(var b=0;b<a.length;b++)try{c(a[b])}catch(d){}}function q(){return d.performance&&d.performance.getEntriesByType?
# d.performance.getEntriesByType("resource"):[]}function n(a){if(a.id)return"//*[@id='"+a.id+"']";var c;c=1;var b;for(b=a.previousSibling;b;b=b.previousSibling)b.nodeName==a.nodeName&&(c+=1);b=a.nodeName;1!=c&&(b+="["+c+"]");a.parentNode&&(b=n(a.parentNode)+"/"+b);return b}function w(){var a=h.images;a&&a.length&&e(a,function(a){var b=a.getAttribute("src");f(b,"img",a);g(b,"img",a)})}function x(){var a=h.scripts;a&&a.length&&e(a,function(a){var b=a.getAttribute("src");f(b,"script",a);g(b,"script",a)})}
# function y(){var a=h.styleSheets;a&&a.length&&e(a,function(a){if(a=a.ownerNode){var b=a.getAttribute("href");f(b,"style",a);g(b,"style",a)}})}function z(){if(A){var a=q();e(a,function(a){f(a.name,a.initiatorType)})}}function B(){e(q(),function(a){g(a.name,a.initiatorType)})}function r(){var a;a=d.location&&d.location.protocol?d.location.protocol:void 0;"https:"==a&&(z(),w(),x(),y(),B(),p<C&&setTimeout(r,D))}var s="[CSM] Insecure content detected ",t="[CSM] Ajax request to same page detected ",v="WARN",
# m={},p=0,D=k.ue_nsip||1E3,C=5,A=1==k.ue_urt,u=!0;ue_csm.ue_disableNonSecure||(d.performance&&d.performance.setResourceTimingBufferSize&&d.performance.setResourceTimingBufferSize(300),r())})(ue_csm,window,document);
#
#
# var ue_aa_a = "";
# if (ue.trigger && (ue_aa_a === "C" || ue_aa_a === "T1")) {
#     ue.trigger("UEDATA_AA_SERVERSIDE_ASSIGNMENT_CLIENTSIDE_TRIGGER_190249", ue_aa_a);
# }
# (function(f,b){function g(){try{b.PerformanceObserver&&"function"===typeof b.PerformanceObserver&&(a=new b.PerformanceObserver(function(b){c(b.getEntries())}),a.observe(d))}catch(h){k()}}function m(){for(var h=d.entryTypes,a=0;a<h.length;a++)c(b.performance.getEntriesByType(h[a]))}function c(a){if(a&&Array.isArray(a)){for(var c=0,e=0;e<a.length;e++){var d=l.indexOf(a[e].name);if(-1!==d){var g=Math.round(b.performance.timing.navigationStart+a[e].startTime);f.uet(n[d],void 0,void 0,g);c++}}l.length===
# c&&k()}}function k(){a&&a.disconnect&&"function"===typeof a.disconnect&&a.disconnect()}if("function"===typeof f.uet&&b.performance&&"object"===typeof b.performance&&b.performance.getEntriesByType&&"function"===typeof b.performance.getEntriesByType&&b.performance.timing&&"object"===typeof b.performance.timing&&"number"===typeof b.performance.timing.navigationStart){var d={entryTypes:["paint"]},l=["first-paint","first-contentful-paint"],n=["fp","fcp"],a;try{m(),g()}catch(p){f.ueLogError(p,{logLevel:"ERROR",
# attribution:"performanceMetrics"})}}})(ue_csm,window);
#
#
# if (window.csa) {
#     csa("Events")("setEntity", {
#         page:{pageType: "title", subPageType: "main", pageTypeId: ""}
#     });
# }
# csa.plugin(function(c){var m="transitionStart",n="pageVisible",e="PageTiming",t="visibilitychange",s="$latency.visible",i=c.global,r=(i.performance||{}).timing,a=["navigationStart","unloadEventStart","unloadEventEnd","redirectStart","redirectEnd","fetchStart","domainLookupStart","domainLookupEnd","connectStart","connectEnd","secureConnectionStart","requestStart","responseStart","responseEnd","domLoading","domInteractive","domContentLoadedEventStart","domContentLoadedEventEnd","domComplete","loadEventStart","loadEventEnd"],u=c.config,o=i.Math,l=o.max,g=o.floor,d=i.document||{},f=(r||{}).navigationStart,v=f,p=0,S=null;if(i.Object.keys&&[].forEach&&!u["KillSwitch."+e]){if(!r||null===f||f<=0||void 0===f)return c.error("Invalid navigation timing data: "+f);S=new E({schemaId:"<ns>.PageLatency.6",producerId:"csa"}),"boolean"!=typeof d.hidden&&"string"!=typeof d.visibilityState||!d.removeEventListener?c.emit(s):b()?(c.emit(s),I(n,f)):c.on(d,t,function e(){b()&&(v=c.time(),d.removeEventListener(t,e),I(m,v),I(n,v),c.emit(s))}),c.once("$unload",h),c.once("$load",h),c.on("$pageTransition",function(){v=c.time()}),c.register(e,{mark:I,instance:function(e){return new E(e)}})}function E(e){var i,r=null,a=e.ent||{page:["pageType","subPageType","requestId"]},o=e.logger||c("Events",{producerId:e.producerId,lob:u.lob||"0"});if(!e||!e.producerId||!e.schemaId)return c.error("The producer id and schema Id must be defined for PageLatencyInstance.");function d(){return i||v}function n(){r=c.UUID()}this.mark=function(n,t){if(null!=n)return t=t||c.time(),n===m&&(i=t),c.once(s,function(){o("log",{messageId:r,__merge:function(e){e.markers[n]=function(e,n){return l(0,n-(e||v))}(d(),t),e.markerTimestamps[n]=g(t)},markers:{},markerTimestamps:{},navigationStartTimestamp:d()?new Date(d()).toISOString():null,schemaId:e.schemaId},{ent:a})}),t},n(),c.on("$beforePageTransition",n)}function I(e,n){e===m&&(v=n);var t=S.mark(e,n);c.emit("$timing:"+e,t)}function h(){if(!p){for(var e=0;e<a.length;e++)r[a[e]]&&I(a[e],r[a[e]]);p=1}}function b(){return!d.hidden||"visible"===d.visibilityState}});csa.plugin(function(c){var f,u,l="length",a="parentElement",t="target",i="getEntriesByName",e=null,r="_csa_flt",o="_csa_llt",s="previousSibling",d="visuallyLoaded",n="client",g="offset",h="scroll",m="Width",p="Height",v=n+m,y=n+p,E=g+m,S=g+p,x=h+m,O=h+p,b="_osrc",w="_elt",I="_eid",T=10,_=5,L=15,N=100,k=c.global,B=c.timeout,H=k.Math,W=H.max,C=H.floor,F=H.ceil,M=k.document||{},R=M.body||{},Y=M.documentElement||{},P=k.performance||{},X=(P.timing||{}).navigationStart,$=Date.now,D=Object.values||(c.types||{}).ovl,J=c("PageTiming"),V=c("SpeedIndexBuffers"),j=[],q=[],z=[],A=[],G=[],K=[],Q=.1,U=.1,Z=0,ee=0,ne=!0,te=0,ie=0,re=1==c.config["SpeedIndex.ForceReplay"],oe=0,ae=1,fe=0,ce={},ue=[],le=0;function se(){for(var e=$(),n=0;f;){if(0!==f[l]){if(!1!==f.h(f[0])&&f.shift(),n++,!re&&n%T==0&&$()-e>_)break}else f=f.n}Z=0,f&&(Z||(!0===M.hidden?(re=1,se()):c.timeout(se,0)))}function de(e,n,t,i,r){fe=C(e),j=n,q=t,z=i,K=r;var o=M.createTreeWalker(M.body,NodeFilter.SHOW_TEXT,null,null),a={w:k.innerWidth,h:k.innerHeight,x:k.pageXOffset,y:k.pageYOffset};M.body[w]=e,A.push({w:o,vp:a}),G.push({img:M.images,iter:0}),j.h=ge,(j.n=q).h=he,(q.n=z).h=me,(z.n=A).h=pe,(A.n=G).h=ve,(G.n=K).h=ye,f=j,se()}function ge(e){e.m.forEach(function(e){for(var n=e;n&&(e===n||!n[r]||!n[o]);)n[r]||(n[r]=e[r]),n[o]||(n[o]=e[o]),n[w]=n[r]-X,n=n[s]})}function he(e){e.m.forEach(function(e){var n=e[t];b in n||(n[b]=e.oldValue)})}function me(n){n.m.forEach(function(e){e[t][w]=n.t-X})}function pe(e){for(var n,t=e.vp,i=e.w,r=T;(n=i.nextNode())&&0<r;){r-=1;var o=(n[a]||{}).nodeName;"SCRIPT"!==o&&"STYLE"!==o&&"NOSCRIPT"!==o&&"BODY"!==o&&0!==(n.nodeValue||"").trim()[l]&&be(n[a],Ee(n),t)}return!n}function ve(e){for(var n={w:k.innerWidth,h:k.innerHeight,x:k.pageXOffset,y:k.pageYOffset},t=T;e.iter<e.img[l]&&0<t;){var i,r=e.img[e.iter],o=Oe(r),a=o&&Ee(o)||Ee(r);o?(o[w]=a,i=xe(o.querySelector('[aria-posinset="1"] img')||r)||a,r=o):i=xe(r)||a ...
#
#
# ue.exec(function(d,c){function g(e,c){e&&ue.tag(e+c);return!!e}function n(){for(var e=RegExp("^https://(.*\.(images|ssl-images|media)-amazon\.com|"+c.location.hostname+")/images/","i"),d={},h=0,k=c.performance.getEntriesByType("resource"),l=!1,b,a,m,f=0;f<k.length;f++)if(a=k[f],0<a.transferSize&&a.transferSize>=a.encodedBodySize&&(b=e.exec(String(a.name)))&&3===b.length){a:{b=a.serverTiming||[];for(a=0;a<b.length;a++)if("provider"===b[a].name){b=b[a].description;break a}b=void 0}b&&(l||(l=g(b,"_cdn_fr")),
# a=d[b]=(d[b]||0)+1,a>h&&(m=b,h=a))}g(m,"_cdn_mp")}d.ue&&"function"===typeof d.ue.tag&&c.performance&&c.location&&n()},"cdnTagging")(ue_csm,window);
#
#
# }
#
# /* ◬ */
# </script>
# </div>
# <noscript>
# <img alt="" height="1" src="//fls-na.amazon.com/1/batch/1/OP/A1EVAM02EL8SFB:136-2930362-6872714:8YE9G7WMYR0TFHZBMGDB$uedata=s:%2Fuedata%2Fuedata%3Fnoscript%26id%3D8YE9G7WMYR0TFHZBMGDB:0" style="display:none;visibility:hidden;" width="1"/>
# </noscript>
# <script>window.ue && ue.count && ue.count('CSMLibrarySize', 61662)</script></div></body></html>

# %%
# Puntuacion
sopa.find("div",{"data-testid":"hero-rating-bar__aggregate-rating__score"}).text
# Out:
# '5,6/10'

# %%
puntuacion = json.loads(sopa.find('script', type='application/json').string)["props"]["pageProps"]["aboveTheFoldData"]["ratingsSummary"]["aggregateRating"]

# %% [markdown]
# Dirección

# %%
direccion = sopa.find_all("li",{"role":"presentation", "class":"ipc-metadata-list__item"})[0].find_all("a")
directores = [director_element.text for director_element in direccion]
direccion_formateado = ", ".join(directores)

# %% [markdown]
# Alternativamente, se podría hacer con:

# %%
json.loads(sopa.find('script', type='application/json').string)["props"]["pageProps"]["aboveTheFoldData"]["principalCredits"][0]["credits"][0]["name"]["nameText"]["text"]
# Out:
# 'Gennadiy Ivanov'

# %% [markdown]
# Guion

# %%
guion = sopa.find_all("li",{"role":"presentation", "class":"ipc-metadata-list__item"})[1].find_all("a")
guionistas = [guion_element.text for guion_element in guion]
guion_formateado = ", ".join(guionistas)
guion_formateado
# Out:
# 'Gennadiy Ivanov, Aleksandr Stashkov'

# %% [markdown]
# Argumento

# %%
plot = json.loads(sopa.find('script', type='application/json').string)["props"]["pageProps"]["aboveTheFoldData"]["plot"]["plotText"]["plainText"]

plot
# Out:
# 'Criminal Investigation Inspector Arkady Ershov is investigating a case related to the Moscow mafia.'

# %% [markdown]
# Duración

# %%
# duracion
duracion = sopa.find("meta",property="og:description")["content"]

def convertir_horas_minutos(duracion):
    # extraer hora
    patron_hora = r"(\d{0,3})h"
    hora = int(re.findall(patron_hora, duracion)[0])

    # extraer minutos
    patron_minutos = r"(\d{0,2})m"
    minutos = int(re.findall(patron_minutos, duracion)[0])

    # duracion total minutos
    return hora*60 + minutos

convertir_horas_minutos(duracion)
# Out:
# 92

# %%
sopa.find_all("meta")

# puntuacion alternativa
sopa.find_all("meta",property="og:title") # aplicar regex extract \d.\d
# Out:
# [<meta content="Shtemp (1991) ⭐ 5.6 | Acción" property="og:title"/>]

# %%
json.loads(sopa.find('script', type='application/json').string)["props"]["pageProps"]
# Out:
# {'tconst': 'tt4495760',
#  'aboveTheFoldData': {'id': 'tt4495760',
#   'productionStatus': {'currentProductionStage': {'id': 'released',
#     'text': 'Estrenada',
#     '__typename': 'ProductionStage'},
#    'productionStatusHistory': [{'status': {'id': 'released',
#       'text': 'Estrenada',
#       '__typename': 'ProductionStatus'},
#      '__typename': 'ProductionStatusHistory'}],
#    'restriction': None,
#    '__typename': 'ProductionStatusDetails'},
#   'canHaveEpisodes': False,
#   'series': None,
#   'titleText': {'text': 'Shtemp', '__typename': 'TitleText'},
#   'titleType': {'displayableProperty': {'value': {'plainText': '',
#      '__typename': 'Markdown'},
#     '__typename': 'DisplayableTitleTypeProperty'},
#    'text': 'Película',
#    'id': 'movie',
#    'isSeries': False,
#    'isEpisode': False,
#    'categories': [{'value': 'movie', '__typename': 'TitleTypeCategory'}],
#    'canHaveEpisodes': False,
#    '__typename': 'TitleType'},
#   'originalTitleText': {'text': 'Shtemp', '__typename': 'TitleText'},
#   'certificate': None,
#   'releaseYear': {'year': 1991, 'endYear': None, '__typename': 'YearRange'},
#   'releaseDate': {'day': None,
#    'month': 9,
#    'year': 1991,
#    '__typename': 'ReleaseDate'},
#   'runtime': {'seconds': 5520,
#    'displayableProperty': {'value': {'plainText': '1h 32min',
#      '__typename': 'Markdown'},
#     '__typename': 'DisplayableTitleRuntimeProperty'},
#    '__typename': 'Runtime'},
#   'canRate': {'isRatable': True, '__typename': 'CanRate'},
#   'ratingsSummary': {'aggregateRating': 5.6,
#    'voteCount': 29,
#    '__typename': 'RatingsSummary'},
#   'meterRanking': None,
#   'primaryImage': {'id': 'rm3031173888',
#    'width': 522,
#    'height': 735,
#    'url': 'https://m.media-amazon.com/images/M/MV5BZTkzMTFmNGItZjRlNS00NDQ1LWIwNzEtODNhYmRhYWRjZWU4XkEyXkFqcGc@._V1_.jpg',
#    'caption': {'plainText': 'Shtemp (1991)', '__typename': 'Markdown'},
#    '__typename': 'Image'},
#   'images': {'total': 1,
#    'edges': [{'node': {'id': 'rm3031173888', '__typename': 'Image'},
#      '__typename': 'ImageEdge'}],
#    '__typename': 'ImageConnection'},
#   'videos': {'total': 0, '__typename': 'TitleRelatedVideosConnection'},
#   'primaryVideos': {'edges': [], '__typename': 'VideoConnection'},
#   'externalLinks': {'total': 0, '__typename': 'ExternalLinkConnection'},
#   'metacritic': None,
#   'keywords': {'total': 6,
#    'edges': [{'node': {'text': 'escape from jail',
#       '__typename': 'TitleKeyword'},
#      '__typename': 'TitleKeywordEdge'},
#     {'node': {'text': 'karate', '__typename': 'TitleKeyword'},
#      '__typename': 'TitleKeywordEdge'},
#     {'node': {'text': 'corrupción', '__typename': 'TitleKeyword'},
#      '__typename': 'TitleKeywordEdge'},
#     {'node': {'text': 'milicia', '__typename': 'TitleKeyword'},
#      '__typename': 'TitleKeywordEdge'},
#     {'node': {'text': 'inspector', '__typename': 'TitleKeyword'},
#      '__typename': 'TitleKeywordEdge'}],
#    '__typename': 'TitleKeywordConnection'},
#   'isAdult': False,
#   'genres': {'genres': [{'text': 'Acción',
#      'id': 'Action',
#      '__typename': 'Genre'}],
#    '__typename': 'Genres'},
#   'interests': {'edges': [{'node': {'id': 'in0000001',
#       'primaryText': {'text': 'Action', '__typename': 'InterestText'},
#       '__typename': 'Interest'},
#      '__typename': 'InterestEdge'}],
#    '__typename': 'InterestConnection'},
#   'plot': {'plotText': {'plainText': 'Criminal Investigation Inspector Arkady Ershov is investigating a case related to the Moscow mafia.',
#     '__typename': 'Markdown'},
#    'language': {'id': 'en-US', '__typename': 'DisplayableLanguage'},
#    '__typename': 'Plot'},
#   'plotContributionLink': {'url': 'https://contribute.imdb.com/updates?update=tt4495760:outlines.add.1.locale~es-ES',
#    '__typename': 'ContributionLink'},
#   'credits': {'total': 23, '__typename': 'CreditConnection'},
#   'principalCredits': [{'totalCredits': 1,
#     'category': {'text': 'Dirección',
#      'id': 'director',
#      '__typename': 'CreditCategory'},
#     'credits': [{'name': {'nameText': {'text': 'Gennadiy Ivanov',
#         '__typename': 'NameText'},
#        'id': 'nm0412042',
#        '__typename': 'Name'},
#       'attributes': None,
#       '__typename': 'Crew'}],
#     '__typename': 'PrincipalCreditsForCategory'},
#    {'totalCredits': 2,
#     'category': {'text': 'Guión',
#      'id': 'writer',
#      '__typename': 'CreditCategory'},
#     'credits': [{'name': {'nameText': {'text': 'Gennadiy Ivanov',
#         '__typename': 'NameText'},
#        'id': 'nm0412042',
#        '__typename': 'Name'},
#       'attributes': None,
#       '__typename': 'Crew'},
#      {'name': {'nameText': {'text': 'Aleksandr Stashkov',
#         '__typename': 'NameText'},
#        'id': 'nm7164976',
#        '__typename': 'Name'},
#       'attributes': None,
#       '__typename': 'Crew'}],
#     '__typename': 'PrincipalCreditsForCategory'},
#    {'totalCredits': 16,
#     'category': {'text': 'Reparto principal',
#      'id': 'cast',
#      '__typename': 'CreditCategory'},
#     'credits': [{'name': {'nameText': {'text': 'Anatoliy Khostikoev',
#         '__typename': 'NameText'},
#        'id': 'nm0451857',
#        '__typename': 'Name'},
#       'attributes': None,
#       '__typename': 'Cast'},
#      {'name': {'nameText': {'text': 'Yelena Kolchugina',
#         '__typename': 'NameText'},
#        'id': 'nm0463967',
#        '__typename': 'Name'},
#       'attributes': None,
#       '__typename': 'Cast'},
#      {'name': {'nameText': {'text': 'Guram Pirtskhalava',
#         '__typename': 'NameText'},
#        'id': 'nm0685345',
#        '__typename': 'Name'},
#       'attributes': None,
#       '__typename': 'Cast'}],
#     '__typename': 'PrincipalCreditsForCategory'}],
#   'reviews': {'total': 1, '__typename': 'ReviewsConnection'},
#   'criticReviewsTotal': {'total': 0, '__typename': 'ExternalLinkConnection'},
#   'triviaTotal': {'total': 0, '__typename': 'TriviaConnection'},
#   'engagementStatistics': None,
#   'subNavCredits': {'total': 23, '__typename': 'CreditConnection'},
#   'subNavReviews': {'total': 1, '__typename': 'ReviewsConnection'},
#   'subNavTrivia': {'total': 0, '__typename': 'TriviaConnection'},
#   'subNavFaqs': {'total': 0, '__typename': 'FaqConnection'},
#   'subNavTopQuestions': {'total': 0, '__typename': 'AlexaQuestionConnection'},
#   'titleGenres': {'genres': [{'genre': {'text': 'Acción',
#       '__typename': 'GenreItem'},
#      '__typename': 'TitleGenre'}],
#    '__typename': 'TitleGenres'},
#   'meta': {'canonicalId': 'tt4495760',
#    'publicationStatus': 'PUBLISHED',
#    '__typename': 'TitleMeta'},
#   'castPageTitle': {'edges': [{'node': {'name': {'id': 'nm0451857',
#        'nameText': {'text': 'Anatoliy Khostikoev', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0463967',
#        'nameText': {'text': 'Yelena Kolchugina', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0685345',
#        'nameText': {'text': 'Guram Pirtskhalava', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0788665',
#        'nameText': {'text': 'Igor Shapovalov', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'}],
#    '__typename': 'CreditConnection'},
#   'creatorsPageTitle': [],
#   'directorsPageTitle': [{'credits': [{'name': {'id': 'nm0412042',
#        'nameText': {'text': 'Gennadiy Ivanov', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Crew'}],
#     '__typename': 'PrincipalCreditsForCategory'}],
#   'countriesOfOrigin': {'countries': [{'id': 'SUHH',
#      '__typename': 'CountryOfOrigin'}],
#    '__typename': 'CountriesOfOrigin'},
#   'production': {'edges': [{'node': {'company': {'id': 'co0114226',
#        'companyText': {'text': 'Fora Film', '__typename': 'CompanyText'},
#        '__typename': 'Company'},
#       '__typename': 'CompanyCredit'},
#      '__typename': 'CompanyCreditEdge'}],
#    '__typename': 'CompanyCreditConnection'},
#   'featuredReviews': {'edges': [], '__typename': 'ReviewsConnection'},
#   '__typename': 'Title'},
#  'mainColumnData': {'id': 'tt4495760',
#   'wins': {'total': 0, '__typename': 'AwardNominationConnection'},
#   'nominationsExcludeWins': {'total': 0,
#    '__typename': 'AwardNominationConnection'},
#   'prestigiousAwardSummary': None,
#   'ratingsSummary': {'topRanking': None, '__typename': 'RatingsSummary'},
#   'episodes': None,
#   'videos': {'total': 0, '__typename': 'TitleRelatedVideosConnection'},
#   'videoStrip': {'edges': [], '__typename': 'VideoConnection'},
#   'titleMainImages': {'total': 1,
#    'edges': [{'node': {'id': 'rm3031173888',
#       'url': 'https://m.media-amazon.com/images/M/MV5BZTkzMTFmNGItZjRlNS00NDQ1LWIwNzEtODNhYmRhYWRjZWU4XkEyXkFqcGc@._V1_.jpg',
#       'caption': {'plainText': 'Shtemp (1991)', '__typename': 'Markdown'},
#       'height': 735,
#       'width': 522,
#       '__typename': 'Image'},
#      '__typename': 'ImageEdge'}],
#    '__typename': 'ImageConnection'},
#   'productionStatus': {'currentProductionStage': {'id': 'released',
#     'text': 'Estrenada',
#     '__typename': 'ProductionStage'},
#    'productionStatusHistory': [{'status': {'id': 'released',
#       'text': 'Estrenada',
#       '__typename': 'ProductionStatus'},
#      '__typename': 'ProductionStatusHistory'}],
#    'restriction': None,
#    '__typename': 'ProductionStatusDetails'},
#   'primaryImage': {'id': 'rm3031173888', '__typename': 'Image'},
#   'inIframeAddLink': {'url': 'https://contribute.imdb.com/image/tt4495760/add?bus=imdb&return_url=https%3A%2F%2Fwww.imdb.com%2Fclose_me&site=web',
#    '__typename': 'ContributionLink'},
#   'notInIframeAddLink': {'url': 'https://contribute.imdb.com/image/tt4495760/add?bus=imdb&return_url=https%3A%2F%2Fwww.imdb.com%2Fes-es%2Ftitle%2Ftt4495760%2F%3Fref_%3Dfn_all_ttl_1&site=mobile',
#    '__typename': 'ContributionLink'},
#   'titleType': {'id': 'movie',
#    'canHaveEpisodes': False,
#    '__typename': 'TitleType'},
#   'cast': {'total': 16,
#    'edges': [{'node': {'name': {'id': 'nm0451857',
#        'nameText': {'text': 'Anatoliy Khostikoev', '__typename': 'NameText'},
#        'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNDNjYWRkMTAtZDQxNC00NzYyLTlhZmMtNTlmYjFlODRhYzMxXkEyXkFqcGc@._V1_.jpg',
#         'width': 640,
#         'height': 368,
#         '__typename': 'Image'},
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Arkadiy Yershov', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0463967',
#        'nameText': {'text': 'Yelena Kolchugina', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actress', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Lyuda', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0685345',
#        'nameText': {'text': 'Guram Pirtskhalava', '__typename': 'NameText'},
#        'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BNjJiNzQ2NTctNjY4OS00YjJkLTk0NWUtZDE5ZDE1YmVkMGQyXkEyXkFqcGc@._V1_.jpg',
#         'width': 446,
#         'height': 338,
#         '__typename': 'Image'},
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': '«Gardener»', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0788665',
#        'nameText': {'text': 'Igor Shapovalov', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Cherkes', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0073415',
#        'nameText': {'text': 'Aleksandr Berda', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Grisha', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0069456',
#        'nameText': {'text': 'Vladimir Belousov', '__typename': 'NameText'},
#        'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYzk3NWM0OTAtOTI0Zi00ODcwLWJjMDQtNmY0YzM4YjlkMzA3XkEyXkFqcGc@._V1_.jpg',
#         'width': 640,
#         'height': 400,
#         '__typename': 'Image'},
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Assistant prosecutor',
#         '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0126462',
#        'nameText': {'text': 'Boris Bystrov', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Colonel', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm7164974',
#        'nameText': {'text': 'Aleksandr Goglidze', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Shota', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0474415',
#        'nameText': {'text': 'Leonid Kulagin', '__typename': 'NameText'},
#        'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BMDEyNDI1NjYtMzVhYy00NjM2LWE1NTMtNDUwMjlkOGQ5ZTA4XkEyXkFqcGc@._V1_.jpg',
#         'width': 688,
#         'height': 416,
#         '__typename': 'Image'},
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Shtemp', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm2355369',
#        'nameText': {'text': 'Yuriy Osipov', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Viktor Grigoryevich Kulakov',
#         '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0699132',
#        'nameText': {'text': 'Nikita Semyonov-Prozorovskiy',
#         '__typename': 'NameText'},
#        'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BYzk4MGYwNDktMDFkMC00ZDhkLWJmOGYtNWMxMTgwOTJlOGYwXkEyXkFqcGc@._V1_.jpg',
#         'width': 287,
#         'height': 387,
#         '__typename': 'Image'},
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Gvozdev', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm7164975',
#        'nameText': {'text': 'Yuriy Sinyakin', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Igor Perovskiy', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0806867',
#        'nameText': {'text': 'Valeriy Smetskoy', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Guram Tskhatkelli', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm0792758',
#        'nameText': {'text': 'Yuriy Sherstnyov', '__typename': 'NameText'},
#        'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BZDQ0NDNiMTQtN2QzMi00MTM1LTlkNzAtZTRkYmRiY2FmNzMwXkEyXkFqcGc@._V1_.jpg',
#         'width': 400,
#         'height': 300,
#         '__typename': 'Image'},
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': [{'name': 'Colonel', '__typename': 'Character'}],
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm2980920',
#        'nameText': {'text': 'Sergei Moiseyev', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': None,
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'},
#     {'node': {'name': {'id': 'nm16548485',
#        'nameText': {'text': 'Aleksandr Vilkov', '__typename': 'NameText'},
#        'primaryImage': None,
#        '__typename': 'Name'},
#       'attributes': None,
#       'category': {'id': 'actor', '__typename': 'CreditCategory'},
#       'characters': None,
#       'episodeCredits': {'total': 0,
#        'yearRange': None,
#        '__typename': 'EpisodeCastConnection'},
#       '__typename': 'Cast'},
#      '__typename': 'CreditEdge'}],
#    '__typename': 'CreditConnection'},
#   'creators': [],
#   'directors': [{'totalCredits': 1,
#     'category': {'text': 'Dirección',
#      'id': 'director',
#      '__typename': 'CreditCategory'},
#     'credits': [{'name': {'id': 'nm0412042',
#        'nameText': {'text': 'Gennadiy Ivanov', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Crew'}],
#     '__typename': 'PrincipalCreditsForCategory'}],
#   'writers': [{'totalCredits': 2,
#     'category': {'text': 'Guión',
#      'id': 'writer',
#      '__typename': 'CreditCategory'},
#     'credits': [{'name': {'id': 'nm0412042',
#        'nameText': {'text': 'Gennadiy Ivanov', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Crew'},
#      {'name': {'id': 'nm7164976',
#        'nameText': {'text': 'Aleksandr Stashkov', '__typename': 'NameText'},
#        '__typename': 'Name'},
#       '__typename': 'Crew'}],
#     '__typename': 'PrincipalCreditsForCategory'}],
#   'isAdult': False,
#   'moreLikeThisTitles': {'edges': [], '__typename': 'MoreLikeThisConnection'},
#   'triviaTotal': {'total': 0, '__typename': 'TriviaConnection'},
#   'trivia': {'edges': [], '__typename': 'TriviaConnection'},
#   'goofsTotal': {'total': 0, '__typename': 'GoofConnection'},
#   'goofs': {'edges': [], '__typename': 'GoofConnection'},
#   'quotesTotal': {'total': 0, '__typename': 'TitleQuoteConnection'},
#   'quotes': {'edges': [], '__typename': 'TitleQuoteConnection'},
#   'crazyCredits': {'edges': [], '__typename': 'CrazyCreditConnection'},
#   'alternateVersions': {'total': 0,
#    'edges': [],
#    '__typename': 'AlternateVersionConnection'},
#   'connections': {'edges': [], '__typename': 'TitleConnectionConnection'},
#   'soundtrack': {'edges': [], '__typename': 'SoundtrackConnection'},
#   'titleText': {'text': 'Shtemp', '__typename': 'TitleText'},
#   'originalTitleText': {'text': 'Shtemp', '__typename': 'TitleText'},
#   'releaseYear': {'year': 1991, '__typename': 'YearRange'},
#   'reviews': {'total': 1, '__typename': 'ReviewsConnection'},
#   'featuredReviews': {'edges': [], '__typename': 'ReviewsConnection'},
#   'canRate': {'isRatable': True, '__typename': 'CanRate'},
#   'iframeAddReviewLink': {'url': 'https://contribute.imdb.com/review/tt4495760/add?bus=imdb&return_url=https%3A%2F%2Fwww.imdb.com%2Fclose_me&site=web',
#    '__typename': 'ContributionLink'},
#   'topQuestions': {'total': 0,
#    'edges': [],
#    '__typename': 'AlexaQuestionConnection'},
#   'faqs': {'total': 0, 'edges': [], '__typename': 'FaqConnection'},
#   'releaseDate': {'day': None,
#    'month': 9,
#    'year': 1991,
#    'country': {'id': 'SUHH',
#     'text': 'Unión Soviética',
#     '__typename': 'LocalizedDisplayableCountry'},
#    '__typename': 'ReleaseDate'},
#   'countriesOfOrigin': {'countries': [{'id': 'SUHH',
#      'text': 'Unión Soviética',
#      '__typename': 'CountryOfOrigin'}],
#    '__typename': 'CountriesOfOrigin'},
#   'detailsExternalLinks': {'edges': [],
#    'total': 0,
#    '__typename': 'ExternalLinkConnection'},
#   'spokenLanguages': {'spokenLanguages': [{'id': 'ru',
#      'text': 'Ruso',
#      '__typename': 'SpokenLanguage'}],
#    '__typename': 'SpokenLanguages'},
#   'akas': {'edges': [{'node': {'text': 'Штемп', '__typename': 'Aka'},
#      '__typename': 'AkaEdge'}],
#    '__typename': 'AkaConnection'},
#   'filmingLocations': {'edges': [],
#    'total': 0,
#    '__typename': 'FilmingLocationConnection'},
#   'production': {'edges': [{'node': {'company': {'id': 'co0114226',
#        'companyText': {'text': 'Fora Film', '__typename': 'CompanyText'},
#        '__typename': 'Company'},
#       '__typename': 'CompanyCredit'},
#      '__typename': 'CompanyCreditEdge'}],
#    '__typename': 'CompanyCreditConnection'},
#   'companies': {'total': 1, '__typename': 'CompanyCreditConnection'},
#   'productionBudget': None,
#   'lifetimeGross': None,
#   'openingWeekendGross': None,
#   'worldwideGross': None,
#   'technicalSpecifications': {'soundMixes': {'items': [],
#     '__typename': 'SoundMixes'},
#    'aspectRatios': {'items': [{'aspectRatio': '1.33 : 1',
#       'attributes': [],
#       '__typename': 'AspectRatio'}],
#     '__typename': 'AspectRatios'},
#    'colorations': {'items': [{'conceptId': 'color',
#       'text': 'Color',
#       'attributes': [],
#       '__typename': 'Coloration'}],
#     '__typename': 'Colorations'},
#    '__typename': 'TechnicalSpecifications'},
#   'runtime': {'seconds': 5520, '__typename': 'Runtime'},
#   'series': None,
#   'canHaveEpisodes': False,
#   'contributionQuestions': {'contributionLink': {'url': 'https://contribute.imdb.com/answers',
#     '__typename': 'ContributionQuestionsLink'},
#    'edges': [{'node': {'entity': {'primaryImage': {'url': 'https://m.media-amazon.com/images/M/MV5BZTkzMTFmNGItZjRlNS00NDQ1LWIwNzEtODNhYmRhYWRjZWU4XkEyXkFqcGc@._V1_.jpg',
#         'width': 522,
#         'height': 735,
#         'caption': {'plainText': 'Shtemp (1991)', '__typename': 'Markdown'},
#         '__typename': 'Image'},
#        '__typename': 'Title'},
#       'questionId': 'tt4495760.title_aka.CA.en-US',
#       'questionText': {'plainText': 'By what name was Shtemp (1991) officially released in Canada in English?',
#        '__typename': 'Markdown'},
#       'contributionLink': {'url': 'https://contribute.imdb.com/answers?pinnedQuestion=tt4495760.title_aka.CA.en-US',
#        '__typename': 'ContributionQuestionsLink'},
#       '__typename': 'Question'},
#      '__typename': 'QuestionEdge'}],
#    '__typename': 'QuestionConnection'},
#   '__typename': 'Title'},
#  'titleCallToAction': {'callToAction': {'titleProUpsell': {'action': {'url': 'https://pro.imdb.com/title/tt4495760/?rf=cons_tt_atf&ref_=cons_tt_atf',
#      'label': {'text': 'Ver la información de la producción en IMDbPro',
#       '__typename': 'CallToActionText'},
#      '__typename': 'ActionLink'},
#     '__typename': 'LinkCallToAction'},
#    '__typename': 'CallToAction'}},
#  'requestContext': {'timestamp': '2024-12-16T14:23:26.363Z',
#   'sidecar': {'account': {'userName': None,
#     'userId': None,
#     'isLoggedIn': False},
#    'placementMap': {'right-3': {'componentName': 'IMDbEditorialSingle',
#      'arguments': {'refTag': 'sw_csegbest_inmem24',
#       'displayTitle': 'In Memoriam 2024',
#       'callToActionUrl': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922',
#       'rmConstForSlateImage': 'rm2312215042',
#       'callToActionText': 'See the gallery',
#       'constId': 'rg1593350144',
#       'description': 'Pay tribute to [link=/name/nm0000469/]James Earl Jones[/link], [link=/name/nm0001167/]Shelley Duvall[/link], and more stars we lost in 2024.',
#       'linkTargetUrl': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922'},
#      'symphonyMetadata': {'contentId': '8d86a373-a88d-425c-9353-ed5d041c2e20',
#       'creativeId': 'eb62f2b7-5254-4e96-bf92-c77dbe4ac920',
#       'placementId': '48daa75d-4975-4fda-8c49-8afaa50ed82f',
#       'msoGroupName': None,
#       'msoSlotOrder': None}},
#     'right-5': {'componentName': 'IMDbEditorialSingle',
#      'arguments': {'refTag': 'csegbest_india_movies_2024',
#       'displayTitle': 'The Top 10 Most Popular Indian Movies of 2024',
#       'callToActionUrl': '/list/ls590529109/',
#       'rmConstForSlateImage': 'rm2172755458',
#       'callToActionText': 'See the list',
#       'constId': 'ls590529109',
#       'description': 'IMDb celebrates the Indian movies that resonated with people worldwide in 2024. Find out who ranked in the top 10!',
#       'linkTargetUrl': '/list/ls590529109/'},
#      'symphonyMetadata': {'contentId': '7429054c-70e3-4397-8272-8c8724c2afd5',
#       'creativeId': '5b995806-feed-495c-b71a-2a17971aeee6',
#       'placementId': 'cbf8965e-7d1a-482d-a0e2-d1b24d97449d',
#       'msoGroupName': None,
#       'msoSlotOrder': None}},
#     'right-7': {'componentName': 'IMDbEditorialSingle',
#      'arguments': {'refTag': 'sw_csegbest_pwl_24',
#       'displayTitle': 'The Year in Pictures',
#       'callToActionUrl': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322',
#       'rmConstForSlateImage': 'rm3576143362',
#       'callToActionText': 'See the gallery',
#       'constId': 'rg3036256256',
#       'description': 'From memorable moments to stunning red carpet looks, check out all our favorite photos of 2024.',
#       'linkTargetUrl': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322'},
#      'symphonyMetadata': {'contentId': '5e9e3641-7ed2-4e99-8213-1a570c6ef5fc',
#       'creativeId': 'e351676c-58cd-42ff-be63-b430e2011e75',
#       'placementId': 'df9f0e05-6574-4e78-bbcf-4199e886a514',
#       'msoGroupName': None,
#       'msoSlotOrder': None}}},
#    'weblabs': {'IMDB_NEXT_EXPERIMENT_MEDIA_GALLERY_WRAPPER_987485': {'T1': True},
#     'IMDB_NEXT_EXPERIMENT_VIDEO_1045917': {'T1': True},
#     'IMDB_NEXT_REDIRECT_SUBPAGES_422235': {'C': True},
#     'IMDB_CENTRALIZED_SEARCH_QUERY_LOGGING_NAV_966369': {'T1': True},
#     'IMDB_REACTION_TASK_COMPLETION_991261': {'T1': True},
#     'IMDB_WEB_FEDV2_1043889': {'C': True},
#     'IMDB_NEXT_1111799': {'T2': True},
#     'IMDB_INTERNATIONAL_SEO_M2_1105188': {'T1': True},
#     'IMDB_NEXT_CLIENT_SIDE_NAVIGATION_323089': {'C': True},
#     'IMDB_418056': {'C': True},
#     'IMDB_BRANCH_KEY_SELECTION_373673': {'C': True},
#     'IMDB_CLIENT_ERROR_PAGE_1105559': {'T1': True},
#     'IMDB_NEXT_USER_PROFILE_PAGE_MODERNIZATION_1008195': {'T1': True},
#     'IMDB_NEXT_DELAY_NAVBAR_QUERY_592650': {'C': True},
#     'IMDB_INTERNATIONAL_SEO_1042314': {'T1': True}},
#    'ads': {'sisPixelMarkup': '',
#     'adSlotsInfo': '{"acceptableClientSideUrl":"https://www.imdb.com/_json/getacceptableads/title?url=https%3A%2F%2Fwww.imdb.com%2Fes-es%2Ftitle%2Ftt4495760%2F%3Fref_%3Dfn_all_ttl_1&subPageType=maindetails&adLayout=title_md&userLanguage=es&targeting=g%3Dac&targeting=c%3D0&targeting=id%3Dtt4495760&targeting=tt%3Df&targeting=coo%3Dsuhh&targeting=md%3Dtt4495760&const=tt4495760","acceptableSlotSizeMap":{"inlinebottom":{"767":"300x250","1023":"728x90","1279":"970x250","9999":"970x250"},"inline40":{"767":"300x250","1023":"300x250","1279":"300x250","9999":"300x250"},"inline50":{"767":"300x250","1023":"728x90","1279":"300x250","9999":"728x90"},"promoted_watch_bar":{"767":"700x150","1023":"700x150","1279":"700x150","9999":"700x150"},"inline60":{"767":"300x250","1023":"300x250","1279":"300x250","9999":"300x250"},"inline80":{"767":"300x250","1023":"300x250","1279":"300x600","9999":"300x600"}},"acceptableSlots":{"inlinebottom":{"slotMarkup":"<!-- Empty inlinebottom -->\\n"},"inline40":{"slotMarkup":"<!-- Empty inline40 -->\\n"},"sis_pixel":{"slotMarkup":"<!-- begin sis pixel slot -->\\n\\n\\n\\n<!-- Begin SIS code -->\\n<script>\\n    if (typeof uet == \'function\') {\\n      uet(\\"bb\\", \\"LoadSis\\", {wb: 1});\\n    }\\n</script>\\n\\n<div id=\\"sis_pixel_r2\\" style=\\"height:1px; position: absolute; left: -1000000px; top: -1000000px;\\">\\n    <iframe id=\\"sis_pixel_sitewide\\" width=\\"1\\" height=\\"1\\" frameborder=\\"0\\" marginwidth=\\"0\\" marginheight=\\"0\\" scrolling=\\"no\\" sandbox=\\"allow-scripts allow-same-origin allow-top-navigation\\" title=\\"sis_pixel_sitewide\\"></iframe>\\n</div>\\n\\n\\n<script>\\n    setTimeout(function() {\\n        var el = document.getElementById(\\"sis_pixel_sitewide\\");\\n        el.src=\\"https://aax-eu.amazon-adsystem.com/s/iu3?d=imdb.com&a1=&a2=&cb=161753056587&pId=tt4495760&r=1&rP=https%3A%2F%2Fwww.imdb.com%2Fes-es%2Ftitle%2Ftt4495760%2F%3Fref_%3Dfn_all_ttl_1&encoding=server&ex-hargs=v%3D1.0%3Bc%3DIMDB%3Bp%3Dtt4495760%3Bt%3Dimdb_title_view%3B&prid=010135930082309d7b60336aaa0fe144b4fe6cca4e726a7f7249052700bdc1048e6c&gdpr=1&gdpr_consent=&gdpr_consent_avl=\\";\\n        el.onload = function() {\\n            if (typeof uex == \'function\') {\\n                uex(\\"ld\\", \\"LoadSis\\", {wb: 1});\\n            }\\n        }\\n    },20);\\n\\n    if (typeof uet == \'function\') {\\n        uet(\\"be\\", \\"LoadSis\\", {wb: 1});\\n    }\\n</script>\\n\\n<!-- End SIS code -->\\n<!-- begin comscore beacon -->\\n<script type=\\"text/javascript\\">\\n    var _comscore = _comscore || [];\\n    _comscore.push({ c1: \\"2\\", c2: \\"6034961\\", cs_ucfr: \\"\\"});\\n    (function() {\\n        var s = document.createElement(\\"script\\"), el = document.getElementsByTagName(\\"script\\")[0]; s.async = true;\\n        s.src = (document.location.protocol == \\"https:\\" ? \\"https://sb\\" : \\"http://b\\") + \\".scorecardresearch.com/beacon.js\\";\\n        el.parentNode.insertBefore(s, el);\\n    })();\\n</script>\\n\\n<noscript>\\n    <img src=\\"https://sb.scorecardresearch.com/p?c1=2&c2=6034961&cj=1&cs_ucfr=\\"/>\\n</noscript>\\n<!-- end comscore beacon -->\\n\\n<!-- end sis pixel slot -->\\n"},"inline50":{"slotMarkup":"<!-- Empty inline50 -->\\n"},"inline60":{"slotMarkup":"<!-- Empty inline60 -->\\n"},"promoted_watch_bar":{"slotMarkup":"{}"},"inline80":{"slotMarkup":"<!-- Empty inline80 -->\\n"}},"adRefreshWebDisabledByBigRedButton":false,"clientSideUrl":"https://www.imdb.com/_json/getads/title?url=https%3A%2F%2Fwww.imdb.com%2Fes-es%2Ftitle%2Ftt4495760%2F%3Fref_%3Dfn_all_ttl_1&subPageType=maindetails&adLayout=title_md&userLanguage=es&targeting=g%3Dac&targeting=c%3D0&targeting=id%3Dtt4495760&targeting=tt%3Df&targeting=coo%3Dsuhh&targeting=md%3Dtt4495760&const=tt4495760","hasPremiumAd":false,"headerMarkup":"<root>\\n<script>\\nwindow.ads_js_start = new Date().getTime();\\nvar imdbads = imdbads || {}; imdbads.cmd = imdbads.cmd || [];\\n</script>\\n<!-- begin ads header -->\\n<script id=\\"ads_tarn ...
#     'adsCcbaConsent': True},
#    'localizationResponse': {'userCountryCode': 'ES',
#     'userLanguage': 'es-ES',
#     'languageForTranslations': 'es-ES',
#     'geolocationCountryCode': 'ES',
#     'gdprCompliantLanguage': 'es-ES',
#     'latitude': '40.41',
#     'longitude': '-3.71',
#     'isOriginalTitlePreferenceSet': False,
#     'isFullLocalizationEnabled': True,
#     'userRegion': 'MD'},
#    'isReferenceViewPreferred': False,
#    'isNewUser': True,
#    'sessionId': '136-2930362-6872714'},
#   'weblabs': {'IMDB_NEXT_EXPERIMENT_MEDIA_GALLERY_WRAPPER_987485': {'T1': True},
#    'IMDB_NEXT_EXPERIMENT_VIDEO_1045917': {'T1': True},
#    'IMDB_NEXT_REDIRECT_SUBPAGES_422235': {'C': True},
#    'IMDB_CENTRALIZED_SEARCH_QUERY_LOGGING_NAV_966369': {'T1': True},
#    'IMDB_REACTION_TASK_COMPLETION_991261': {'T1': True},
#    'IMDB_WEB_FEDV2_1043889': {'C': True},
#    'IMDB_NEXT_1111799': {'T2': True},
#    'IMDB_INTERNATIONAL_SEO_M2_1105188': {'T1': True},
#    'IMDB_NEXT_CLIENT_SIDE_NAVIGATION_323089': {'C': True},
#    'IMDB_418056': {'C': True},
#    'IMDB_BRANCH_KEY_SELECTION_373673': {'C': True},
#    'IMDB_CLIENT_ERROR_PAGE_1105559': {'T1': True},
#    'IMDB_NEXT_USER_PROFILE_PAGE_MODERNIZATION_1008195': {'T1': True},
#    'IMDB_NEXT_DELAY_NAVBAR_QUERY_592650': {'C': True},
#    'IMDB_INTERNATIONAL_SEO_1042314': {'T1': True}},
#   'pageType': 'title',
#   'subPageType': 'main',
#   'pageConst': 'tt4495760',
#   'refTagPrefix': 'tt',
#   'headers': {'x-forwarded-for': '188.227.145.112, 72.21.217.96',
#    'x-forwarded-proto': 'https',
#    'x-forwarded-port': '443',
#    'host': 'www.imdb.com',
#    'x-amzn-trace-id': 'Root=1-676037de-02594bf65410fbf60ea87d32',
#    'x-forwarded-host': 'www.imdb.com',
#    'x-forwarded-server': 'www.imdb.com',
#    'user-agent': 'Chrome',
#    'x-amz-rid': '8YE9G7WMYR0TFHZBMGDB',
#    'x-autobahn-via': 'CloudFront',
#    'x-autobahn-header-order': 'Host:User-Agent:Accept-Encoding:Accept:Connection',
#    'x-amzn-header-count': '5',
#    'x-amzn-ci-http-version': '1.1',
#    'x-amz-cx-family': 'imdb',
#    'x-amz-cx-id': 'imdb.com',
#    'x-original-uri': '/es-es/title/tt4495760/',
#    'x-original-args': 'ref_=fn_all_ttl_1',
#    'x-original-method': 'GET',
#    'x-original-scheme': 'https',
#    'original-x-forwarded-for': '188.227.145.112',
#    'x-amzn-tenant-id': 'www.imdb.com',
#    'x-amzn-domain-name': 'www.imdb.com',
#    'x-amazon-frontier': 'cf',
#    'accept': '*/*',
#    'accept-encoding': 'gzip, deflate',
#    'x-opf-egress': '0',
#    'x-amazon-urlspace': 'NoPageType',
#    'x-amazon-internal-ip-location': 'Country=ES;',
#    'x-amazon-internal-ip-class': 'external',
#    'x-amzn-route-id': '1.CUxPS9AguU6wuy5_kI_D4w.0'},
#   'requestId': '8YE9G7WMYR0TFHZBMGDB',
#   'isInternal': False,
#   'ipAddress': '188.227.145.112',
#   'queryParams': {'ref_': 'fn_all_ttl_1', 'tconst': 'tt4495760'},
#   'isIMDbAppWebView': False,
#   'requestPath': '/es-es/title/tt4495760/?ref_=fn_all_ttl_1',
#   'requestUri': 'https://www.imdb.com'},
#  'cmsContext': {'transformedPlacements': {'right-3': {'componentName': 'IMDbEditorialSingle',
#     'arguments': {'refTag': 'sw_csegbest_inmem24',
#      'displayTitle': 'In Memoriam 2024',
#      'callToActionUrl': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922',
#      'rmConstForSlateImage': 'rm2312215042',
#      'callToActionText': 'See the gallery',
#      'constId': 'rg1593350144',
#      'description': 'Pay tribute to [link=/name/nm0000469/]James Earl Jones[/link], [link=/name/nm0001167/]Shelley Duvall[/link], and more stars we lost in 2024.',
#      'linkTargetUrl': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922',
#      'generatedPrefix': 'tt_eds_right-3',
#      'slotName': 'right-3'},
#     'symphonyMetadata': {'contentId': '8d86a373-a88d-425c-9353-ed5d041c2e20',
#      'creativeId': 'eb62f2b7-5254-4e96-bf92-c77dbe4ac920',
#      'placementId': '48daa75d-4975-4fda-8c49-8afaa50ed82f',
#      'msoGroupName': None,
#      'msoSlotOrder': None},
#     'transformedArguments': {'refTag': 'sw_csegbest_inmem24',
#      'displayTitle': 'In Memoriam 2024',
#      'callToActionUrl': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922',
#      'rmConstForSlateImage': 'rm2312215042',
#      'callToActionText': 'See the gallery',
#      'constId': 'rg1593350144',
#      'description': 'Pay tribute to <a class="ipc-md-link" href="/name/nm0000469/?ref_=tt_eds_right-3_lk">James Earl Jones</a>, <a class="ipc-md-link" href="/name/nm0001167/?ref_=tt_eds_right-3_lk">Shelley Duvall</a>, and more stars we lost in 2024.',
#      'linkTargetUrl': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922',
#      'generatedPrefix': 'tt_eds_right-3',
#      'slotName': 'right-3',
#      'iconName': 'collections',
#      'errors': [],
#      'overlayCaption': 'editorialSingle_label_photos',
#      'linkedImages': [{'imageModel': {'url': 'https://m.media-amazon.com/images/M/MV5BNDc1Mzk5ODktZTVhNC00MTI2LWE3OWEtZTYxZTQ0MTJjZWIyXkEyXkFqcGc@._V1_.jpg',
#         'maxHeight': 702,
#         'maxWidth': 1248,
#         'caption': 'Product image'},
#        'link': '/best-of/in-memoriam-2024/rg1593350144/mediaviewer/rm1137809922'}]},
#     'queryTypeFlags': {'image': True, 'gallery': True}},
#    'right-5': {'componentName': 'IMDbEditorialSingle',
#     'arguments': {'refTag': 'csegbest_india_movies_2024',
#      'displayTitle': 'The Top 10 Most Popular Indian Movies of 2024',
#      'callToActionUrl': '/list/ls590529109/',
#      'rmConstForSlateImage': 'rm2172755458',
#      'callToActionText': 'See the list',
#      'constId': 'ls590529109',
#      'description': 'IMDb celebrates the Indian movies that resonated with people worldwide in 2024. Find out who ranked in the top 10!',
#      'linkTargetUrl': '/list/ls590529109/',
#      'generatedPrefix': 'tt_eds_right-5',
#      'slotName': 'right-5'},
#     'symphonyMetadata': {'contentId': '7429054c-70e3-4397-8272-8c8724c2afd5',
#      'creativeId': '5b995806-feed-495c-b71a-2a17971aeee6',
#      'placementId': 'cbf8965e-7d1a-482d-a0e2-d1b24d97449d',
#      'msoGroupName': None,
#      'msoSlotOrder': None},
#     'transformedArguments': {'refTag': 'csegbest_india_movies_2024',
#      'displayTitle': 'The Top 10 Most Popular Indian Movies of 2024',
#      'callToActionUrl': '/list/ls590529109/',
#      'rmConstForSlateImage': 'rm2172755458',
#      'callToActionText': 'See the list',
#      'constId': 'ls590529109',
#      'description': 'IMDb celebrates the Indian movies that resonated with people worldwide in 2024. Find out who ranked in the top 10!',
#      'linkTargetUrl': '/list/ls590529109/',
#      'generatedPrefix': 'tt_eds_right-5',
#      'slotName': 'right-5',
#      'iconName': 'list',
#      'errors': [],
#      'overlayCaption': 'editorialSingle_label_list',
#      'linkedImages': [{'imageModel': {'url': 'https://m.media-amazon.com/images/M/MV5BOGUxYmUzM2ItNDZhNi00Y2JiLTg5MjktODZmZTNkZDQ1Njg5XkEyXkFqcGc@._V1_.jpg',
#         'maxHeight': 1080,
#         'maxWidth': 1920,
#         'caption': 'Poster'},
#        'link': '/list/ls590529109/'}]},
#     'queryTypeFlags': {'image': True}},
#    'right-7': {'componentName': 'IMDbEditorialSingle',
#     'arguments': {'refTag': 'sw_csegbest_pwl_24',
#      'displayTitle': 'The Year in Pictures',
#      'callToActionUrl': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322',
#      'rmConstForSlateImage': 'rm3576143362',
#      'callToActionText': 'See the gallery',
#      'constId': 'rg3036256256',
#      'description': 'From memorable moments to stunning red carpet looks, check out all our favorite photos of 2024.',
#      'linkTargetUrl': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322',
#      'generatedPrefix': 'tt_eds_right-7',
#      'slotName': 'right-7'},
#     'symphonyMetadata': {'contentId': '5e9e3641-7ed2-4e99-8213-1a570c6ef5fc',
#      'creativeId': 'e351676c-58cd-42ff-be63-b430e2011e75',
#      'placementId': 'df9f0e05-6574-4e78-bbcf-4199e886a514',
#      'msoGroupName': None,
#      'msoSlotOrder': None},
#     'transformedArguments': {'refTag': 'sw_csegbest_pwl_24',
#      'displayTitle': 'The Year in Pictures',
#      'callToActionUrl': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322',
#      'rmConstForSlateImage': 'rm3576143362',
#      'callToActionText': 'See the gallery',
#      'constId': 'rg3036256256',
#      'description': 'From memorable moments to stunning red carpet looks, check out all our favorite photos of 2024.',
#      'linkTargetUrl': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322',
#      'generatedPrefix': 'tt_eds_right-7',
#      'slotName': 'right-7',
#      'iconName': 'collections',
#      'errors': [],
#      'overlayCaption': 'editorialSingle_label_photos',
#      'linkedImages': [{'imageModel': {'url': 'https://m.media-amazon.com/images/M/MV5BOTllYTBiNzctZDk1OS00M2I5LTkwOGMtZWIzODYwZDZhNjM4XkEyXkFqcGc@._V1_.jpg',
#         'maxHeight': 2107,
#         'maxWidth': 3746,
#         'caption': 'Production art'},
#        'link': '/best-of/photos-we-love-2024/rg3036256256/mediaviewer/rm757112322'}]},
#     'queryTypeFlags': {'image': True, 'gallery': True}}},
#   'isValid': True,
#   'isDebug': False},
#  'translationContext': {'i18n': {'translations': {'resources': {'accountSettings_account_settings': 'Configuración de la cuenta',
#      'accountSettings_account_deletion_confirmation_header': '¿Seguro de que quieres eliminar tu cuenta?',
#      'accountSettings_delete_account': 'Eliminar cuenta',
#      'accountSettings_deleting_your_account_header': 'Eliminar tu cuenta es una operación permanente',
#      'accountSettings_feedback_title': 'Valoración',
#      'accountSettings_get_help_completing_registration_link_text': 'Obtener ayuda para completar el registro',
#      'accountSettings_id': 'ID',
#      'accountSettings_imdb_faq_link_text': 'Preguntas frecuentes de IMDb',
#      'accountSettings_joined': 'Se ha unido',
#      'accountSettings_privacy_policy_link_text': 'Política de privacidad',
#      'accountSettings_registration_info_title': 'Información de registro',
#      'accountSettings_registration_faq_link_text': 'Preguntas frecuentes sobre el registro',
#      'accountSettings_request_account_deletion_button_label': 'Solicitar la eliminación de la cuenta',
#      'accountSettings_submit_account_deletion_request_button_label': 'Enviar solicitud de eliminación de la cuenta',
#      'accountSettings_tell_us_what_you_think_link_text': 'Dinos qué piensas de esta función',
#      'accountSettings_your_account_details': 'Detalles de tu cuenta:',
#      'accountSettings_your_account_settings_link_text': 'Configuración de mi cuenta',
#      'ad_feedback_error_link': 'Si el problema continúa, contáctanos en el centro de ayuda de IMDb.',
#      'ad_feedback_error_message': 'Se ha producido un error en esta página.',
#      'addConstToListMenuItem_goToList_ariaLabel': 'Ir a la lista: {listTitle}',
#      'addConstToListPrompt_label_createList': 'Crear nueva lista',
#      'addConstToListPrompt_no_lists_found': 'No se han encontrado listas',
#      'alexa_explain_name_textP1': 'Amazon Alexa genera automáticamente respuestas a estas preguntas frecuentes a partir de otros tipos de datos de IMDb. Por ejemplo, la fecha de nacimiento de Denzel Washington aparece en su página de IMDb. Alexa utiliza esto para generar automáticamente una respuesta a la pregunta “¿Cuántos años tiene Denzel Washington?”.',
#      'alexa_explain_name_textP2': 'A diferencia de las preguntas frecuentes normales, los colaboradores de IMDb no pueden editar directamente estos elementos generados por Alexa. Si observas algún problema con un elemento generado por Alexa, envía la corrección a los datos de origen utilizados para generar la respuesta. Por ejemplo, si la respuesta a “¿Cuántos años tiene Denzel Washington?” es incorrecta, puedes enviar una corrección a su fecha de nacimiento (al hacer clic en “Editar” junto a ella).',
#      'alexa_explain_title_textP1': 'Amazon Alexa genera automáticamente respuestas a estas preguntas frecuentes a partir de otros tipos de datos de IMDb. Por ejemplo, la recaudación total bruta mundial de Batman Begins (2005) aparece en la portada de IMDb. Alexa utiliza esto para generar automáticamente una respuesta a la pregunta “¿Cuánto recaudó Batman Begins en taquilla?”.',
#      'alexa_explain_title_textP2': 'A diferencia de las preguntas frecuentes normales, los colaboradores de IMDb no pueden editar directamente estos elementos generados por Alexa. Si observas algún problema con un elemento generado por Alexa, envía la corrección a los datos de origen utilizados para generar la respuesta. Por ejemplo, si la respuesta a “¿Cuánto recaudó Batman Begins en taquilla?” era incorrecta, para corregirla tendrías que corregir los datos de recaudación total bruta (hacer clic en “Editar” junto a ellos).',
#      'alexa_explain_contactCTA': 'Para cualquier otro problema, ponte en contacto con nosotros.',
#      'alexa_explain_title': 'Sobre las preguntas principales con tecnología de Alexa',
#      'awards_subpage_meta_description': 'Premios, nominaciones y ganadores',
#      'awards_subpage_meta_keywords': 'Premios, Nominaciones, Oscar, MTV Movie Awards, Emmy, Ganador, Nominado, Nominado',
#      'awards_subpage_shared_with': 'Compartido con:',
#      'autotranslation_translationEnabled': 'Traducciones automáticas están activadas.',
#      'autotranslation_translationBetaMessage': 'Estás viendo la versión beta de IMDb en {displayLanguage}, disponible para fans del entretenimiento en {country}.',
#      'autotranslation_translationIndicatorMessage': 'Este símbolo {indicatorIcon} indica que el contenido se ha traducido automáticamente.',
#      'background_label': 'Fondo',
#      'background_option_dark': 'Oscuro / IMDb',
#      'background_option_light': 'Claro / IMDbPro',
#      'bornToday_header': 'Personas nacidas hoy',
#      'bornToday_header_description_date': 'Personas nacidas el {dateString}',
#      'breadcrumb_label_back': 'Atrás',
#      'breadcrumb_label_home': 'Inicio',
#      'calendar_page_countrySelector_label': 'Seleccionar país',
#      'calendar_page_filter_type_movie': 'Película',
#      'calendar_page_filter_type_tv': 'TV',
#      'calendar_page_filter_type_tvEpisode': 'Episodio de televisión',
#      'calendar_page_results_empty': 'No hemos encontrado ningún resultado para tu consulta.',
#      'calendar_page_title': 'Próximos lanzamientos',
#      'chart_box_office_mojo_link': 'Ve más resultados de carteleras en BoxOfficeMojo.com',
#      'chart_no_results_heading': 'No se han encontrado resultados',
#      'chart_no_results_sub_heading': 'Ajusta los filtros.',
#      'chart_box_office_reported_by': 'Notificado por',
#      'chart_box_office_title': 'Películas más taquilleras (EE.\xa0UU.)',
#      'chart_box_office_title_description': 'Fin de semana del {dateRange}',
#      'chart_box_office_title_description_sidebar': 'Del fin de semana pasado',
#      'chart_imdb_charts': 'Tablas de IMDb',
#      'chart_info_button_aria_label': 'Ver más información sobre {target}',
#      'chart_learn_more': 'Obtén más información sobre cómo se determina la clasificación de las listas.',
#      'chart_lowest_rated_movies_disclaimer': 'La lista de películas peor valoradas solo incluye largometrajes. Los cortometrajes, las películas de televisión y los documentales no están incluidos. La lista se clasifica según una fórmula que incluye la cantidad de calificaciones que cada película recibió de los usuarios y el valor de las calificaciones recibidas de los usuarios habituales. Para figurar en la lista, una película debe recibir calificaciones de al menos 10\xa0000\xa0usuarios.',
# ...
#       'common_language_QAK': 'Teochew',
#       'common_language_QAM': 'Acholi',
#       'common_language_QAN': 'Tigrigna',
#       'common_language_QAO': 'Ryukyuan',
#       'common_language_QAP': 'Malinka',
#       'common_language_QAQ': 'Kriolu',
#       'common_language_QAR': 'Kirundi',
#       'common_language_QAS': 'Aidoukrou',
#       'common_language_QAT': 'Ungwatsi',
#       'common_language_QAU': 'Shanxi',
#       'common_language_QAV': 'Hassanya',
#       'common_language_QAW': 'Djerma',
#       'common_language_QAX': 'Chaozhou',
#       'common_language_QAY': 'Dialectos escanianos',
#       'common_language_QAZ': 'Ojihimba',
#       'common_language_QBA': 'Nama',
#       'common_language_QBB': 'Kuna',
#       'common_language_QBC': 'Groenlandés oriental',
#       'common_language_QBD': 'Baka',
#       'common_language_QBE': 'Sousson',
#       'common_language_QBF': 'Kaado',
#       'common_language_QBG': 'Faliasch',
#       'common_language_QBH': 'Bodo',
#       'common_language_QBI': 'Bicolano',
#       'common_language_QBJ': 'Rawan',
#       'common_language_QBK': 'Nushi',
#       'common_language_QBL': 'Nagpuri',
#       'common_language_QBM': 'Macro-Jê',
#       'common_language_QBN': 'Flamenco',
#       'common_language_QBO': 'Serbocroata',
#       'common_language_QMT': 'Mixteco',
#       'common_language_QSG': 'Silbo gomero',
#       'common_language_QU': 'Quechua',
#       'common_language_QYA': 'Quenya',
#       'common_language_RAJ': 'Rayastani',
#       'common_language_RM': 'Romanche',
#       'common_language_RO': 'Rumano',
#       'common_language_ROM': 'Romaní',
#       'common_language_RSL': 'Lengua de signos rusa',
#       'common_language_RTM': 'Rotumano',
#       'common_language_RU': 'Ruso',
#       'common_language_RW': 'Kinyarwanda',
#       'common_language_SA': 'Sánscrito',
#       'common_language_SAH': 'Yakuto',
#       'common_language_SAT': 'Santalí',
#       'common_language_SC': 'Sardo',
#       'common_language_SCN': 'Siciliano',
#       'common_language_SD': 'Sindhi',
#       'common_language_SHH': 'Shoshoni',
#       'common_language_SHP': 'Shipibo',
#       'common_language_SI': 'Cingalés',
#       'common_language_SIO': 'Sioux',
#       'common_language_SJN': 'Sindarin',
#       'common_language_SK': 'Eslovaco',
#       'common_language_SL': 'Esloveno',
#       'common_language_SM': 'Samoano',
#       'common_language_SN': 'Shona',
#       'common_language_SNK': 'Soninké',
#       'common_language_SO': 'somalí',
#       'common_language_SON': 'Songhay',
#       'common_language_SQ': 'Albanés',
#       'common_language_SR': 'Serbio',
#       'common_language_SRN': 'Sranan',
#       'common_language_SRR': 'Serer',
#       'common_language_SSP': 'Lengua de signos española',
#       'common_language_ST': 'Sesoto',
#       'common_language_SV': 'Sueco',
#       'common_language_SW': 'Suajili',
#       'common_language_SYL': 'Silhetí',
#       'common_language_TA': 'Tamil',
#       'common_language_TAC': 'Tarahumara',
#       'common_language_TCY': 'Tulu',
#       'common_language_TE': 'Telugu',
#       'common_language_TG': 'Tayiko',
#       'common_language_TH': 'Tailandés',
#       'common_language_TK': 'Turcomano',
#       'common_language_TL': 'Tagalo',
#       'common_language_TLH': 'Klingon',
#       'common_language_TLI': 'Tlingit',
#       'common_language_TMH': 'Tamazight',
#       'common_language_TN': 'Tsuana',
#       'common_language_TO': 'Tongano (Islas Tonga)',
#       'common_language_TPI': 'Tok Pisin',
#       'common_language_TR': 'Turco',
#       'common_language_TRP': 'Kokborok',
#       'common_language_TS': 'Tsonga',
#       'common_language_TSC': 'Tswa',
#       'common_language_TSZ': 'Purépecha',
#       'common_language_TT': 'Tártaro',
#       'common_language_TUE': 'Tuyuco',
#       'common_language_TUP': 'Tupí',
#       'common_language_TYV': 'Tuvano',
#       'common_language_TZO': 'Tzotzil',
#       'common_language_UK': 'Ucraniano',
#       'common_language_UKL': 'Lengua de signos ucraniana',
#       'common_language_UR': 'Urdu',
#       'common_language_UZ': 'Uzbeko',
#       'common_language_VI': 'Vietnamita',
#       'common_language_WAS': 'Washo',
#       'common_language_WEN': 'Idiomas sórabos',
#       'common_language_WO': 'Wólof',
#       'common_language_XAL': 'Calmuco-oirate',
#       'common_language_XH': 'Xhosa',
#       'common_language_XRR': 'Rético',
#       'common_language_YAP': 'Yapese',
#       'common_language_YI': 'Yidis',
#       'common_language_YO': 'Yoruba',
#       'common_language_YPK': 'Yupik',
#       'common_language_YRK': 'Nénets',
#       'common_language_YUE': 'Cantonés',
#       'common_language_ZH': 'Chino',
#       'common_language_ZU': 'Zulú',
#       'common_language_ZXX': 'Ninguno',
#       'common_last_modified': 'actualizado hace {duration}',
#       'common_launch_message': 'Te damos la bienvenida a la nueva versión de esta página.',
#       'common_learnMore': 'Más información',
#       'common_length_exceeded': '{length, plural, one {{length} caracteres por encima del límite} other {{length} caracteres por encima del límite}}',
#       'common_length_remaining': '{length} de {maxLength}\xa0caracteres',
#       'common_length_text_remaining': '{length, plural, one {{length} carácter restante} other {{length} caracteres restantes}}',
#       'common_linkCopied': 'Enlace copiado',
#       'common_listItem_notInterested': 'No me interesa',
#       'common_listItem_episode': 'Episodio',
#       'common_more': 'Más',
#       'common_mostRecent': 'Más reciente',
#       'common_mediaIndex_title': 'Imágenes',
#       'common_meta_description': 'Películas, televisión, celebridades y más...',
#       'common_metascore': 'Metapuntuación',
#       'common_minihero_subtitle_metadata': '({text})',
#       'common_motion_picture_rating': 'Calificación de películas (MPAA)',
#       'common_name_age_meta': '({age})',
#       'common_name_born': 'Nacimiento',
#       'common_name_died': 'Fallecimiento',
#       'common_name_faq': 'Preguntas frecuentes',
#       'common_name_generalContribution_cta': 'Ayuda a contribuir a IMDb. Añade una biografía, curiosidades y más.',
#       'common_name_personal_quote': 'Citas',
#       'common_name_salaries': '{totalSalaries, plural, one {Salario} other {Salarios}}',
#       'common_name_starmeter_currentRank_top10000': 'Los 10 000 mejores',
#       'common_name_starmeter_currentRank_top500': 'Los 500 mejores',
#       'common_name_starmeter_currentRank_top5000': 'Los 5 000 mejores',
#       'common_name_starmeter_seeRank': 'Ver clasificación',
#       'common_name_topQuestions': 'Preguntas principales de Alexa',
#       'common_name_trademark': '{totalTrademarks, plural, one {Marca comercial} other {Marcas comerciales}}',
#       'common_news_byline': 'por {author}',
#       'common_news_disclaimer': 'IMDb.com, Inc. no se hace responsable del contenido o la precisión de los artículos de noticias, tuits o publicaciones de blog anteriores. Este contenido se publica únicamente para el entretenimiento de nuestros usuarios. Los artículos de noticias, los tuits y las publicaciones de blog no representan las opiniones de IMDb ni podemos garantizar que los informes que contienen sean completamente objetivos. Visita la fuente responsable del artículo en cuestión para informarle sobre cualquier duda que puedas tener con respecto al contenido o su nivel de precisión.',
#       'common_news_meta_keywords': 'Noticias, reseñas, horarios, fotos, foros, calificaciones, sinopsis, tráileres, créditos',
#       'common_openapp': 'Abrir la aplicación',
#       'common_news_permalink': 'Enlace permanente',
#       'common_news_reportThis': 'Denunciar esto',
#       'common_news_subpage_title': 'Noticias',
#       'common_not_you_question': '¿No eres tú?',
#       'common_open_filter_prompt': 'Abrir aviso de filtro',
#       'common_over': 'superior a',
#       'common_pagination_count': '{current}\xa0de {total}',
#       'common_pagination_loadAll': 'Todo',
#       'common_pagination_next': 'Siguiente',
#       'common_pagination_previous': 'Anterior',
#       'common_pagination_remaining': '{remaining} más',
#       'common_parents': 'Padres',
#       'common_parentsGuide_label': 'Guía parental',
#       'common_people': 'Personas',
#       'common_photos_addLabel': 'Añadir foto',
#       'common_privacy_setting': 'Configuración de privacidad',
#       'common_provided_by': 'Proporcionado por ',
#       'common_ratingPrompt_ariaLabelPrefix': 'Puntuar',
#       'common_ratingPrompt_didntWatch': 'No me pidas que califique',
#       'common_ratingPrompt_error': 'No se puede puntuar el título. Inténtalo de nuevo más tarde.',
#       'common_ratingPrompt_header': 'Puntúame',
#       'common_ratingPrompt_rate': 'Puntuar',
#       'common_ratingPrompt_removeRating': 'Borrar puntuación',
#       'common_ratingPrompt_titleText': '¿Cómo puntuarías {titleTextString}?',
#       'common_region_AD': 'Andorra',
#       'common_region_AE': 'Emiratos Árabes Unidos',
#       'common_region_AF': 'Afganistán',
#       'common_region_AG': 'Antigua y Barbuda',
#       'common_region_AI': 'Anguilla',
#       'common_region_AL': 'Albania',
#       'common_region_AM': 'Armenia',
#       'common_region_AN': 'Antillas holandesas',
#       'common_region_AO': 'Angola',
#       'common_region_AQ': 'Antártida',
#       'common_region_AR': 'Argentina',
#       'common_region_AS': 'Samoa\xa0Americana',
#       'common_region_AT': 'Austria',
#       'common_region_AU': 'Australia',
#       'common_region_AW': 'Aruba',
#       'common_region_AX': 'Islas Åland',
#       'common_region_AZ': 'Azerbaiyán',
#       'common_region_BA': 'Bosnia y Herzegovina',
#       'common_region_BB': 'Barbados',
#       'common_region_BD': 'Bangladesh',
#       'common_region_BE': 'Bélgica',
#       'common_region_BF': 'Burkina\xa0Faso',
#       'common_region_BG': 'Bulgaria',
#       'common_region_BH': 'Baréin',
#       'common_region_BI': 'Burundi',
#       'common_region_BJ': 'Benín',
#       'common_region_BL': 'San Bartolomé',
#       'common_region_BM': 'Bermudas',
#       'common_region_BN': 'Brunéi',
#       'common_region_BO': 'Bolivia',
#       'common_region_BQ': 'Caribe Neerlandés',
#       'common_region_BR': 'Brasil',
#       'common_region_BS': 'Bahamas',
#       'common_region_BT': 'Bután',
#       'common_region_BUMM': 'Birmania',
#       'common_region_BV': 'Isla Bouvet',
#       'common_region_BW': 'Botsuana',
#       'common_region_BY': 'Bielorrusia',
#       'common_region_BZ': 'Belice',
#       'common_region_CA': 'Canadá',
#       'common_region_CC': 'Islas Cocos (Keeling)',
#       'common_region_CD': 'Congo - Kinshasa',
#       'common_region_CF': 'República Centroafricana',
#       'common_region_CG': 'Congo - Brazzaville',
#       'common_region_CH': 'Suiza',
#       'common_region_CI': 'Costa de Marfil',
#       'common_region_CK': 'Islas Cook',
#       'common_region_CL': 'Chile',
#       'common_region_CM': 'Camerún',
#       'common_region_CN': 'China',
#       'common_region_CO': 'Colombia',
#       'common_region_CR': 'Costa Rica',
#       'common_region_CSHH': 'Checoslovaquia',
#       'common_region_CSXX': 'Serbia y Montenegro',
#       'common_region_CU': 'Cuba',
#       'common_region_CV': 'Cabo Verde',
#       'common_region_CW': 'Curazao',
#       'common_region_CX': 'Isla de Navidad',
#       'common_region_CY': 'Chipre',
#       'common_region_CZ': 'Chequia',
#       'common_region_DDDE': 'Alemania del Este',
#       'common_region_DE': 'Alemania',
#       'common_region_DJ': 'Yibuti',
#       'common_region_DK': 'Dinamarca',
#       'common_region_DM': 'Dominica',
#       'common_region_DO': 'República Dominicana',
#       'common_region_DZ': 'Argelia',
#       'common_region_EC': 'Ecuador',
#       'common_region_EE': 'Estonia',
#       'common_region_EG': 'Egipto',
#       'common_region_EH': 'Sáhara Occidental',
#       'common_region_ER': 'Eritrea',
#       'common_region_ES': 'España',
#       'common_region_ET': 'Etiopía',
#       'common_region_FI': 'Finlandia',
#       'common_region_FJ': 'Fiyi',
#       'common_region_FK': 'Islas Malvinas',
#       'common_region_FM': 'Micronesia',
#       'common_region_FO': 'Islas Feroe',
#       'common_region_FR': 'Francia',
#       'common_region_GA': 'Gabón',
#       'common_region_GB': 'Reino Unido',
#       'common_region_GD': 'Granada',
#       'common_region_GE': 'Georgia',
#       'common_region_GF': 'Guayana Francesa',
#       'common_region_GG': 'Guernsey',
#       'common_region_GH': 'Ghana',
#       'common_region_GI': 'Gibraltar',
#       'common_region_GL': 'Groenlandia',
#       'common_region_GM': 'Gambia',
#       'common_region_GN': 'Guinea',
#       'common_region_GP': 'Guadalupe',
#       'common_region_GQ': 'Guinea Ecuatorial',
#       'common_region_GR': 'Grecia',
#       'common_region_GS': 'Islas Georgias del Sur y Sándwich del Sur',
#       'common_region_GT': 'Guatemala',
#       'common_region_GU': 'Guam',
#       'common_region_GW': 'Guinea-Bisáu',
#       'common_region_GY': 'Guyana',
#       'common_region_HK': 'RAE de Hong Kong de China',
#       'common_region_HM': 'Islas Heard y McDonald',
#       'common_region_HN': 'Honduras',
#       'common_region_HR': 'Croatia',
#       'common_region_HT': 'Haití',
#       'common_region_HU': 'Hungría',
#       'common_region_ID': 'Indonesia',
#       'common_region_IE': 'Irlanda',
#       'common_region_IL': 'Israel',
#       'common_region_IM': 'Isla de Man',
#       'common_region_IN': 'India',
#       'common_region_IO': 'Territorio Británico del Océano Índico',
#       'common_region_IQ': 'Irak',
#       'common_region_IR': 'Irán',
#       'common_region_IS': 'Islandia',
#       'common_region_IT': 'Italia',
#       'common_region_JE': 'Jersey',
#       'common_region_JM': 'Jamaica',
#       'common_region_JO': 'Jordania',
#       'common_region_JP': 'Japón',
#       'common_region_KE': 'Kenia',
#       'common_region_KG': 'Kirguistán',
#       'common_region_KH': 'Camboya',
#       'common_region_KI': 'Kiribati',
#       'common_region_KM': 'Comoros',
#       'common_region_KN': 'San Cristóbal y Nieves',
#       'common_region_KP': 'Corea del Norte',
#       'common_region_KR': 'Corea del Sur',
#       'common_region_KW': 'Kuwait',
#       'common_region_KY': 'Islas Caimán',
#       'common_region_KZ': 'Kazajistán',
#       'common_region_LA': 'Laos',
#       'common_region_LB': 'Líbano',
#       'common_region_LC': 'Santa Lucía',
#       'common_region_LI': 'Liechtenstein',
#       'common_region_LK': 'Sri Lanka',
#       'common_region_LR': 'Liberia',
#       'common_region_LS': 'Lesoto',
#       'common_region_LT': 'Lituania',
#       'common_region_LU': 'Luxemburgo',
#       'common_region_LV': 'Letonia',
#       'common_region_LY': 'Libia',
#       'common_region_MA': 'Marruecos',
#       'common_region_MC': 'Mónaco',
#       'common_region_MD': 'Moldavia',
#       'common_region_ME': 'Montenegro',
#       'common_region_MF': 'San Martín',
#       'common_region_MG': 'Madagascar',
#       'common_region_MH': 'Islas\xa0Marshall',
#       'common_region_MK': 'República de Macedonia del Norte',
#       'common_region_ML': 'Mali',
#       'common_region_MM': 'Myanmar (Birmania)',
#       'common_region_MN': 'Mongolia',
#       'common_region_MO': 'RAE de Macao de China',
#       'common_region_MP': 'Islas Marianas del Norte',
#       'common_region_MQ': 'Martinica',
#       'common_region_MR': 'Mauritania',
#       'common_region_MS': 'Montserrat',
#       'common_region_MT': 'Malta',
#       'common_region_MU': 'Mauricio',
#       'common_region_MV': 'Maldivas',
#       'common_region_MW': 'Malawi',
#       'common_region_MX': 'México',
#       'common_region_MY': 'Malasia',
#       'common_region_MZ': 'Mozambique',
#       'common_region_NA': 'Namibia',
#       'common_region_NC': 'a Nueva\xa0Caledonia',
#       'common_region_NE': 'Níger',
#       'common_region_NF': 'Isla Norfolk',
#       'common_region_NG': 'Nigeria',
#       'common_region_NI': 'Nicaragua',
#       'common_region_NL': 'Países Bajos',
#       'common_region_NO': 'Noruega',
#       'common_region_NP': 'Nepal',
#       'common_region_NR': 'Nauru',
#       'common_region_NU': 'Niue',
#       'common_region_NZ': 'Nueva\xa0Zelanda',
#       'common_region_OM': 'Omán',
#       'common_region_PA': 'Panamá',
#       'common_region_PE': 'Perú',
#       'common_region_PF': 'Polinesia Francesa',
#       'common_region_PG': 'Papúa Nueva Guinea',
#       'common_region_PH': 'Filipinas',
#       ...}}},
#    'locale': 'es-ES'}},
#  'urqlState': None,
#  'fetchState': None}

# %%
sopa.find_all("div",{"class":"ipc-html-content ipc-html-content--base"})
# Out:
# []

# %% [markdown]
# ## 2.2 Realizar peticiones para los ids unicos:

# %% [markdown]
# Creacion de funciones asincronas para las consultas de los ids.

# %%
async def request_movies_imdb_async(url, headers):
    async with aiohttp.ClientSession() as session:
        async with session.get(url=url,headers=headers) as response:
            if response.status == 500:
                print(f"Max operation time for url {url}. Retrying...")
                await asyncio.sleep(3)  # Wait for 3 seconds before retrying
                return await request_movies_imdb_async(url, headers)  # Retry the same request
            elif response.status == 200:
                results = await response.text()
            #         results = await response.json()
            #         pagina = results["page"]
            #         results = results["results"]
            #         for result in results:
            #             result["pagina"] = pagina
            #             result["genre"] = querystring["genre"]

            #     except KeyError as e:
            #         print(f"KeyError with querystring {querystring}: {e}")
            #         return []  # returning an empty list for consistency
            #     except TypeError as e:
            #         print(f"TypeError with querystring {querystring}: {e}")
            #         return []
            #     except Exception as e:
            #         print(f"Unexpected error with querystring {querystring}: {e}")
            #         return []
            # else:
            #     print(f"Request failed with status {response.status} for {querystring}")
            #     return []
            #     raise ValueError(f"HTTP Error: {response.status}")
                return results


async def gather_with_concurrency(n, *coros):
    semaphore = asyncio.Semaphore(n)

    async def sem_coro(coro):
        async with semaphore:
            return await coro
    return await asyncio.gather(*(sem_coro(c) for c in coros))     

async def get_movies_info(url_list, headers): 

    tasks = [request_movies_imdb_async(url, headers) for url in url_list]
    results = await gather_with_concurrency(64,*tasks)

    return results

# %% [markdown]
# Prueba con 2 urls.

# %%
urls = ["https://www.imdb.com/es-es/title/tt4495760/?ref_=fn_all_ttl_1","https://www.imdb.com/es-es/title/tt0252196/"]
resultados = await get_movies_info(urls,headers)
resultados
# Out:
# [None, None]

# %% [markdown]
# Funciones de parseado y formateado de información.

# %%
def parse_with_bs(content):
    sopa = BeautifulSoup(content, "html.parser")

    try:
        page_props = json.loads(sopa.find('script', type='application/json').string)["props"]["pageProps"]
        puntuacion =  get_score(page_props)
        plot = get_plot(page_props)
    except:
        puntuacion =  None
        plot = None


    informacion_pelicula = {
        "id": page_props["tconst"],
        "puntuacion": puntuacion,
        "argumento": plot,
        "direccion": get_direccion(sopa),
        "guionistas": get_guionistas(sopa),
        "duracion": get_duracion(sopa)

    }
    
    return informacion_pelicula

def parse_all_contents(list_of_contents):
    results = Parallel(n_jobs=-1)(
        delayed(parse_with_bs)(content)
        for content in tqdm(list_of_contents)
    )

    return results 

def get_score(page_props):

    return page_props["aboveTheFoldData"]["ratingsSummary"]["aggregateRating"]

def get_direccion(sopa):
    try:
        direccion = sopa.find_all("li",{"role":"presentation", "class":"ipc-metadata-list__item"})[0].find_all("a")
        directores = [director_element.text for director_element in direccion]
        direccion_formateado = ", ".join(directores)
    except:
        direccion_formateado = None

    return direccion_formateado

def get_guionistas(sopa):
    try: 
        guion = sopa.find_all("li",{"role":"presentation", "class":"ipc-metadata-list__item"})[1].find_all("a")
        guionistas = [guion_element.text for guion_element in guion]
        guion_formateado = ", ".join(guionistas)
    
    except:
        guion_formateado = None

    return guion_formateado

def get_plot(page_props):

    return page_props["aboveTheFoldData"]["plot"]["plotText"]["plainText"]

def convertir_horas_minutos(duracion):
    # extraer hora
    patron_hora = r"(\d{0,3})h"
    hora = int(re.findall(patron_hora, duracion)[0])

    # extraer minutos
    patron_minutos = r"(\d{0,2})m"
    minutos = int(re.findall(patron_minutos, duracion)[0])

    # duracion total minutos
    return hora*60 + minutos

def get_duracion(sopa):
    duracion = sopa.find("meta",property="og:description")["content"]

    duracion_formateada = convertir_horas_minutos(duracion)

    return duracion_formateada

# %% [markdown]
# Prueba de resultados

# %%
pd.DataFrame(parse_all_contents(resultados))
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 220.94it/s]
#           id  puntuacion                                          argumento  \
# 0  tt4495760         5.6  Criminal Investigation Inspector Arkady Ershov...
# 1  tt0252196         8.4  A group of children use a time machine to inve...
#
#                  direccion                                   guionistas  \
# 0          Gennadiy Ivanov          Gennadiy Ivanov, Aleksandr Stashkov
# 1  Singeetam Srinivasa Rao  Guión, Jandhyala, Singeetam Srinivasa Rao,
#
#    duracion
# 0        92
# 1       140

# %% [markdown]
# ### 2.2.2 Aplicación a todos los ids unicos

# %%
peliculas_df = pd.read_csv("../data/movies_total.csv",index_col=0)
peliculas_df.head()
# Out:
#    pagina         id tipo_titulo                          titulo genero   año  \
# 0       1  tt0059325       movie                     Jahrgang 45  Drama  1990
# 1       1  tt0059900       movie  Wenn du groß bist, lieber Adam  Drama  1990
# 2       1  tt0065188       movie         Vojtech, receny sirotek  Drama  1990
# 3       1  tt0068494       movie                    Domo Arigato  Drama  1990
# 4       1  tt0075259       movie                       Spy Story  Drama  1990
#
#     mes
# 0  10.0
# 1  10.0
# 2  10.0
# 3   8.0
# 4   3.0

# %% [markdown]
# Obtencion de lista de urls:

# %%
lista_de_ids = peliculas_df["id"].to_list()
lista_de_urls = []

for id in lista_de_ids:
    url = f"https://www.imdb.com/es-es/title/{id}/"
    lista_de_urls.append(url)

lista_de_urls[:5]
# Out:
# ['https://www.imdb.com/es-es/title/tt0059325/',
#  'https://www.imdb.com/es-es/title/tt0059900/',
#  'https://www.imdb.com/es-es/title/tt0065188/',
#  'https://www.imdb.com/es-es/title/tt0068494/',
#  'https://www.imdb.com/es-es/title/tt0075259/']

# %% [markdown]
# Obtencion de resultados de consultas:

# %%
resultados_consultas = await get_movies_info(lista_de_urls[:100],headers)
resultados_consultas
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# Filtrando por peliculas de 'Horror'

# %%
peliculas_df
# Out:
#        pagina          id tipo_titulo               titulo    genero   año  \
# 9337       12  tt19797422       short        Resarcimiento    Action  2022
# 16602      21  tt18849138       short       The Black Hand    Horror  2022
# 1556        2  tt14405434       short  Something Wonderful  Thriller  2021
# 11578      15  tt19466142       movie          Meatgrinder  Thriller  2021
# 1852       28   tt0312843       movie       Jisatsu sâkuru   Mystery  2021
# ...       ...         ...         ...                  ...       ...   ...
# 19265      25   tt0132408       movie          Party Plane    Comedy  1989
# 73          1   tt0096075       movie               Sexpot    Comedy  1988
# 3065        4  tt27036639       short        Gloomy Sunday   Mystery  1988
# 12084      16   tt0092984       movie    Esto es un atraco    Comedy  1987
# 4419       31   tt0167319       short                Urzad     Drama  1966
#
#         mes
# 9337    NaN
# 16602   3.0
# 1556   11.0
# 11578  11.0
# 1852    5.0
# ...     ...
# 19265   2.0
# 73     11.0
# 3065   10.0
# 12084   5.0
# 4419    NaN
#
# [30018 rows x 7 columns]

# %%
peliculas_df.sort_values(by="año", inplace=True, ascending=False)
lista_de_ids = peliculas_df.loc[(peliculas_df["genero"]=="Horror") & (peliculas_df["año"] == 2000),"id"].to_list()
lista_de_urls = []

for id in lista_de_ids:
    url = f"https://www.imdb.com/es-es/title/{id}/"
    lista_de_urls.append(url)

len(lista_de_urls)
# Out:
# 286

# %%
resultados_consultas = await get_movies_info(lista_de_urls,headers)
resultados_consultas
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# Las consultas son demasiadas
